# %% [markdown]
# # Options & Data

# %%
# %load_ext autoreload
# %autoreload 2

import os
import re
import functools
import numpy as np
import pandas as pd
import corescpy as cr

# Display
pd.options.display.max_colwidth = 1000
pd.options.display.max_columns = 100
pd.options.display.max_rows = 500

# Count Threshold for Cell Quantification
count_threshold = 1

# File Paths
panel = "TUQ97N"
libid = "Stricture-50403C1"
direc = "/mnt/cho_lab/bbdata2/"
dir_data = os.path.join(direc, f"outputs/{panel}")
dir_writeable = "/mnt/cho_lab/disk2/elizabeth/data/shared-xenium-library"
out_dir = os.path.join(dir_writeable, "outputs/TUQ97N/nebraska")
mdf = os.path.join(dir_writeable, "samples.csv")  # metadata
path_ann = "~/corescpy/examples/markers_lineages.csv"

# Constants
constants_dict = cr.get_panel_constants(panel_id=panel)
cso, csid, col_condition, col_inflamed, col_stricture, key_stricture = [
    constants_dict[x] if x in constants_dict else None for x in [
        "col_sample_id_o", "col_sample_id", "col_condition", "col_inflamed",
        "col_stricture", "key_stricture"]]  # column & keys in columns

# Clustering Version
c_t = "leiden_res1pt5_dist0_npc30"  # high resolution
# c_t = "leiden_res0pt75_dist0pt3_npc30"  # medium resolution
# c_t = "leiden_res0pt5_dist0pt5_npc30"  # low resolution

# ToppGene Sources & Quantification Count Threshold
srcs = ["Cells of the human intestinal tract mapped across space and time",
        "Human Ileal Epithelial cells from Crohn’s Disease",
        "Human Ileal Immune cells from Crohn’s Disease"]
count_threshold = 1

# Annotation Guide File
anf = pd.read_csv(path_ann)
col_assignment = "group"
assign = anf.dropna(subset=col_assignment).set_index(
    "gene").rename_axis("Gene")  # markers

# Metadata & List of Existing Xenium Data Directories
metadata = (pd.read_excel if mdf[-4:] == "xlsx" else pd.read_csv)(mdf)
if col_stricture is not None and col_condition not in metadata.columns:
    metadata.loc[:, col_condition] = metadata.apply(
        lambda x: key_stricture.capitalize() if x[
            col_stricture].lower() in ["yes", key_stricture.lower()] else x[
                col_inflamed].capitalize(), axis=1)
metadata.loc[:, csid] = metadata[col_condition] + "-" + metadata[cso]
samp_ids = dict(metadata.set_index(cso)[csid])  # map libid to condition-ID
files = functools.reduce(lambda i, j: i + j, [[os.path.join(
    run, i) for i in os.listdir(os.path.join(
        dir_data, run))] for run in os.listdir(dir_data)])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Data

# %%
# Load Spatial Data
file_path = np.array(files)[np.where(["-".join(libid.split(
    "-")[1:]) == os.path.basename(x).split("__")[2].split(
        "-")[0] for x in files])[0][0]]  # find file for sample
self = cr.Spatial(os.path.join(dir_data, file_path), library_id=libid)
self.update_from_h5ad(os.path.join(out_dir, libid + ".h5ad"))
self.get_layer("counts", inplace=True)

# Write Cluster Files
# self.write_clusters(out_dir, col_cell_type=c, overwrite=True,
#                     file_prefix=f"{self._library_id}__", n_top=True)
# Out:
# <<< INITIALIZING SPATIAL CLASS OBJECT >>>
#
# INFO     reading
#          /mnt/cho_lab/bbdata2/outputs/TUQ97N/CHO-012/output-XETG00189__0021978__50403C1-TUQ97N-EA__20240516__190239
#          /cell_feature_matrix.h5
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
#
#
# ================================================================================
# Counts: Initial
# ================================================================================
#
#
# 	Observations: 722162
#
# 	Genes: 469
#
#
#
# ================================================================================
#
#
#
#
#  AnnData object with n_obs × n_vars = 722162 × 469
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'region', 'z_level', 'nucleus_count', 'cell_labels', 'Sample'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatialdata_attrs', 'spatial', 'original_ix'
#     obsm: 'spatial'
#     layers: 'counts'
#
#                       gene_ids    feature_types   genome
# gene_symbols
# ABCA7         ENSG00000064687  Gene Expression  Unknown
# ACTA2         ENSG00000107796  Gene Expression  Unknown
# ACTG2         ENSG00000163017  Gene Expression  Unknown
# ADAM15        ENSG00000143537  Gene Expression  Unknown
# ADAM28        ENSG00000042980  Gene Expression  Unknown
#
#
#
#
#
# col_gene_symbols="gene_symbols"
# col_cell_type="leiden"
# col_sample_id="Sample"
# col_batch="Sample"
# col_subject=None
# col_condition=None
# col_num_umis=None
# col_segment="region"
#
#
#
# key_control=None
# key_treatment=None
#
#
# <<< RESTORING SINGLE-SAMPLE FROM h5ad >>>
#
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# AnnData object with n_obs × n_vars = 653622 × 469
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'region', 'z_level', 'nucleus_count', 'cell_labels', 'Sample', 'Sample ID', 'Patient', 'Status', 'Slide Id', 'Project', 'Location', 'Stricture', 'GRID ID', 'Inflamed', 'Procedure Date', 'Age', 'Sex', 'Race', 'Hispanic', 'Diagnosis', 'Project.1', 'Procedure', 'Disease_Status', 'Date Collected', 'Date Sectioned', 'Date Hybridization', 'Storage 4c', 'Created By', 'Created', 'Storage Status', 'Location.1', 'Storage Row', 'Storage Col', 'Checked Out By', 'Unnamed: 29', 'out_file', 'segmentation', 'Condition', 'file_path', 'n_counts', 'log_counts', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'assay_protein', 'col_gene_symbols', 'col_cell_type', 'col_sample_id', 'col_batch', 'col_subject', 'col_condition', 'col_num_umis', 'col_segment', 'cell_filter_pmt', 'cell_filter_ncounts', 'cell_filter_ngene', 'gene_filter_ncell', 'gene_filter_ncounts', 'custom_thresholds', 'method_norm', 'figsize', 'kws_scale', 'leiden_res1pt5_dist0_npc30', 'label_res1pt5_dist0_npc30', 'Name', 'Inflammation'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'Sample_colors', 'hvg', 'label_res1pt5_dist0_npc30_colors', 'leiden_res1pt5_dist0_npc30', 'log1p', 'neighbors', 'original_ix', 'pca', 'rank_genes_groups_leiden_res1pt5_dist0_npc30', 'spatialdata_attrs', 'specifications', 'umap', 'spatial'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'counts', 'log1p', 'scaled'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # ToppGene

# %%
self.get_layer("counts", inplace=True)
tgdf, mks = self.annotate_clusters(
        None, sources=srcs, col_cell_type=c_t, max_results=10000,
        name_pattern={srcs[0]: "SmallIntestine"},
        # p_threshold=1e-15,
        p_threshold=1e-2,
        lfc_threshold=1, n_top_genes=20, n_top_annotations=40)
longs = [(" / Per Region, Age_group, Lineage, cell class, cell type", ""),
         ("SmallIntestine", "SmInt")]
for x in longs:
    tgdf.loc[:, "Name"] = tgdf.Name.apply(lambda y: re.sub(x[0], x[1], y))
tgdf.loc[:, "Name"] = tgdf.Name.apply(lambda y: "|".join(y.split("|")[
        :-1]) if y.split("|")[-1].split("-")[0] in y.split("-")[0] and (any(
            i in y for i in ["Child", "Adult", "Pediatric", "Trim"])) else y)
tgdf = tgdf.rename_axis([c_t, "Rank"])
tgdf = tgdf.join(tgdf.apply(
    lambda x: f"{x['GenesInTermInQuery']} / {x['GenesInQuery']}",
    axis=1).to_frame("Marker Matches"))
tgdf = tgdf[list(tgdf.columns[:1]) + ["Marker Matches"] + list(
        tgdf.columns[1:-1])]
tgdf = tgdf.rename_axis([c_t, "Rank"])
tgdf
# Out:
#                                                                                                                    Name  \
# leiden_res1pt5_dist0_npc30 Rank
# 16                         0                                                                  SmInt_Adult-Hematopoietic
#                            1                             SmInt_GW_trimst-1-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-1
#                            2               SmInt_GW_trimst-1-Hematopoietic-T_cells-LTi-like_NCR-_ILC3|SmInt_GW_trimst-1
#                            3                                                     SmInt_Adult-Hematopoietic-Myeloid-cDC2
#                            4                                                  SmInt_Pediatric_IBD-Hematopoietic-Myeloid
#                            5                             SmInt_GW_trimst-2-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-2
#                            6                             SmInt_GW_trimst-2-Hematopoietic-T_cells-ILCP|SmInt_GW_trimst-2
#                            7                                SmInt_Child04-06-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            8                             SmInt_GW_trimst-1-Hematopoietic-T_cells-ILCP|SmInt_GW_trimst-1
#                            9           SmInt_GW_trimst-1.5-Hematopoietic-T_cells-LTi-like_NCR+_ILC3|SmInt_GW_trimst-1.5
# 0                          0                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgA_plasma_cell
#                            1                                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells
#                            2                                SmInt_Child09-12-Hematopoietic-Plasma_cells-IgA_plasma_cell
#                            3                                                SmInt_Child09-12-Hematopoietic-Plasma_cells
#                            4                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            5                                SmInt_Child04-06-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            6                                SmInt_Child09-12-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            7                                SmInt_Child04-06-Hematopoietic-Plasma_cells-IgA_plasma_cell
# 2                          0                                                 SmInt_Child09-12-Hematopoietic-T_cells-Tfh
#                            1                                              SmInt_Pediatric_IBD-Hematopoietic-T_cells-Tfh
#                            2                      SmInt_GW_trimst-2-Hematopoietic-T_cells-Activated_T|SmInt_GW_trimst-2
# 20                         0                            SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
#                            1                         SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
#                            2                                    SmInt_Adult-Mesenchymal-fibroblastic-Stromal_1_(CCL11+)
#                            3                                                            SmInt_Pediatric_IBD-Mesenchymal
#                            4                            SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
#                            5         SmInt_GW_trimst-2-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|SmInt_GW_trimst-2
#                            6                                               SmInt_Pediatric_IBD-Mesenchymal-fibroblastic
#                            7                                                               SmInt_Child04-06-Mesenchymal
#                            8                                                               SmInt_Child09-12-Mesenchymal
#                            9         SmInt_GW_trimst-1-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|SmInt_GW_trimst-1
#                            10                              SmInt_GW_trimst-1-Mesenchymal-fibroblastic|SmInt_GW_trimst-1
#                            11                                                 SmInt_Child04-06-Mesenchymal-fibroblastic
#                            12                                                 SmInt_Child09-12-Mesenchymal-fibroblastic
#                            13                              SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_1_(CCL11+)
#                            14                              SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(CCL11+)
#                            15                           SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-Stromal_1_(CCL11+)
#                            16                                SmInt_Adult-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
#                            17    SmInt_GW_trimst-1.5-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|SmInt_GW_trimst-1.5
#                            18                              SmInt_GW_trimst-2-Mesenchymal-fibroblastic|SmInt_GW_trimst-2
#                            19                                SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
#                            20                                SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
#                            21                             SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
#                            22             SmInt_GW_trimst-2-Mesenchymal-fibroblastic-Stromal_2_(NPY+)|SmInt_GW_trimst-2
#                            23                          SmInt_GW_trimst-1.5-Mesenchymal-fibroblastic|SmInt_GW_trimst-1.5
#                            24                                       SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
#                            25                                         SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-mLTo
# 12                         0                                                  SmInt_Adult-Epithelial-goblet-Goblet_cell
#                            1                                                              SmInt_Adult-Epithelial-goblet
#                            2                      SmInt_GW_trimst-1.5-Epithelial-goblet-Goblet_cell|SmInt_GW_trimst-1.5
#                            3                          SmInt_GW_trimst-1-Epithelial-goblet-Goblet_cell|SmInt_GW_trimst-1
#                            4                                      SmInt_GW_trimst-1-Epithelial-goblet|SmInt_GW_trimst-1
#                            5                                  SmInt_GW_trimst-1.5-Epithelial-goblet|SmInt_GW_trimst-1.5
#                            6                                  SmInt_Pediatric_IBD-Epithelial-epithelial_progenitor_cell
#                            7                               SmInt_Pediatric_IBD-Epithelial-epithelial_progenitor_cell-TA
#                            8                                      SmInt_Child04-06-Epithelial-mature_enterocytic-Paneth
#                            9                                   SmInt_Pediatric_IBD-Epithelial-goblet-BEST2+_Goblet_cell
#                            10              SmInt_GW_trimst-1.5-Epithelial-mature_enterocytic-Paneth|SmInt_GW_trimst-1.5
#                            11         SmInt_GW_trimst-1.5-Epithelial-Tuft-related-BEST4+_epithelial|SmInt_GW_trimst-1.5
#                            12                           SmInt_GW_trimst-1.5-Epithelial-Tuft-related|SmInt_GW_trimst-1.5
#                            13                               SmInt_GW_trimst-1-Epithelial-Tuft-related|SmInt_GW_trimst-1
#                            14             SmInt_GW_trimst-1-Epithelial-Tuft-related-BEST4+_epithelial|SmInt_GW_trimst-1
#                            15       Enterocyte_Progenitors-C_06|Enterocyte_Progenitors / shred on cell type and cluster
#                            16                                         SmInt_Pediatric_IBD-Epithelial-goblet-Goblet_cell
#                            17                                    SmInt_Child09-12-Epithelial-epithelial_progenitor_cell
#                            18                                                     SmInt_Pediatric_IBD-Epithelial-goblet
#                            19                                            SmInt_Child09-12-Epithelial-goblet-Goblet_cell
#                            20                                                        SmInt_Child09-12-Epithelial-goblet
#                            21                                 SmInt_Child09-12-Epithelial-epithelial_progenitor_cell-TA
#                            22                              SmInt_Adult-Epithelial-epithelial_progenitor_cell-Stem_cells
#                            23                                         SmInt_Adult-Epithelial-epithelial_progenitor_cell
#                            24                                      SmInt_Adult-Epithelial-epithelial_progenitor_cell-TA
# 19                         0                   SmInt_GW_trimst-2-Hematopoietic-Myeloid-CLC+_Mast_cell|SmInt_GW_trimst-2
#                            1                        SmInt_GW_trimst-2-Hematopoietic-Myeloid-Mast_cell|SmInt_GW_trimst-2
#                            2                                           SmInt_Child09-12-Hematopoietic-Myeloid-Mast_cell
#                            3               SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-CLC+_Mast_cell|SmInt_GW_trimst-1.5
#                            4                                                SmInt_Adult-Hematopoietic-Myeloid-Mast_cell
#                            5                                           SmInt_Child04-06-Hematopoietic-Myeloid-Mast_cell
#                            6                                        SmInt_Pediatric_IBD-Hematopoietic-Myeloid-Mast_cell
#                            7                                           SmInt_Adult-Epithelial-mature_enterocytic-Paneth
# 8                          0                                SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            1                SmInt_GW_trimst-2-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-2
#                            2                                   SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            3            SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1.5
#                            4                SmInt_GW_trimst-1-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1
#                            5                                        SmInt_Adult-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 28                         0                                                 SmInt_Child04-06-Hematopoietic-Myeloid-pDC
#                            1                                              SmInt_Pediatric_IBD-Hematopoietic-Myeloid-pDC
#                            2                              SmInt_GW_trimst-1-Hematopoietic-Myeloid-pDC|SmInt_GW_trimst-1
#                            3                              SmInt_GW_trimst-2-Hematopoietic-Myeloid-pDC|SmInt_GW_trimst-2
#                            4                          SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-pDC|SmInt_GW_trimst-1.5
# 14                         0                                   SmInt_Pediatric_IBD-Hematopoietic-B_cells-Cycling_B_cell
#                            1                                      SmInt_Child04-06-Hematopoietic-B_cells-Cycling_B_cell
#                            2                                      SmInt_Child09-12-Hematopoietic-B_cells-Cycling_B_cell
#                            3                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgA_plasma_cell
#                            4                                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells
# 5                          0                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgA_plasma_cell
#                            1                                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells
#                            2                                SmInt_Child09-12-Hematopoietic-Plasma_cells-IgA_plasma_cell
#                            3                                                SmInt_Child09-12-Hematopoietic-Plasma_cells
#                            4                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            5                                SmInt_Child04-06-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            6                                SmInt_Child09-12-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            7                                SmInt_Child04-06-Hematopoietic-Plasma_cells-IgA_plasma_cell
# 21                         0                                           SmInt_Child09-12-Hematopoietic-Myeloid-Mast_cell
#                            1                                           SmInt_Child04-06-Hematopoietic-Myeloid-Mast_cell
#                            2                        SmInt_GW_trimst-2-Hematopoietic-Myeloid-Mast_cell|SmInt_GW_trimst-2
#                            3                                                SmInt_Adult-Hematopoietic-Myeloid-Mast_cell
#                            4                                        SmInt_Pediatric_IBD-Hematopoietic-Myeloid-Mast_cell
# 17                         0                                                  SmInt_Pediatric_IBD-Mesenchymal-Pericytes
#                            1                                         SmInt_Pediatric_IBD-Mesenchymal-Pericytes-Pericyte
#                            2                                                     SmInt_Child04-06-Mesenchymal-Pericytes
#                            3                                            SmInt_Child04-06-Mesenchymal-Pericytes-Pericyte
#                            4                SmInt_GW_trimst-1-Mesenchymal-Pericytes-Immature_pericyte|SmInt_GW_trimst-1
#                            5         SmInt_GW_trimst-2-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|SmInt_GW_trimst-2
#                            6                                 SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
#                            7                                 SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
#                            8                              SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
#                            9                                                            SmInt_Pediatric_IBD-Mesenchymal
#                            10                           SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
#                            11                                                              SmInt_Child04-06-Mesenchymal
#                            12                                                              SmInt_Child09-12-Mesenchymal
#                            13                           SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
#                            14                                         SmInt_Child04-06-Neuronal-Glial_mature-Adult_Glia
#                            15                                                                 SmInt_Child04-06-Neuronal
#                            16                                                    SmInt_Child04-06-Neuronal-Glial_mature
#                            17                                 SmInt_GW_trimst-1-Mesenchymal-Pericytes|SmInt_GW_trimst-1
#                            18                                    SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
#                            19                                       SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
# 29                         0                                SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            1                                   SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            2                       SmInt_Child04-06-Hematopoietic-Myeloid-MMP9+_Inflammatory_macrophage
#                            3                                                     SmInt_Child09-12-Hematopoietic-Myeloid
# 13                         0                                     SmInt_Child04-06-Hematopoietic-B_cells-FCRL4+_Memory_B
#                            1                                                          SmInt_Adult-Hematopoietic-B_cells
#                            2                                                 SmInt_Adult-Hematopoietic-B_cells-Memory_B
#                            3                                                                     SmInt_Child04-06|World
#                            4                                            SmInt_Child09-12-Hematopoietic-B_cells-Memory_B
#                            5                            SmInt_GW_trimst-1-Hematopoietic-B_cells-Pre-B|SmInt_GW_trimst-1
# 15                         0                                  SmInt_GW_trimst-2-Hematopoietic-Myeloid|SmInt_GW_trimst-2
#                            1                              SmInt_GW_trimst-1.5-Hematopoietic-Myeloid|SmInt_GW_trimst-1.5
#                            2                      SmInt_GW_trimst-2-Hematopoietic-Myeloid-Macrophages|SmInt_GW_trimst-2
#                            3                  SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-Macrophages|SmInt_GW_trimst-1.5
#                            4                                SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            5                                        SmInt_Adult-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            6                                                     SmInt_Adult-Hematopoietic-Myeloid-cDC2
#                            7                             SmInt_GW_trimst-2-Hematopoietic-Myeloid-cDC2|SmInt_GW_trimst-2
#                            8                                      SmInt_Pediatric_IBD-Hematopoietic-Myeloid-Macrophages
#                            9                                              SmInt_Adult-Hematopoietic-Myeloid-Macrophages
#                            10                                 SmInt_GW_trimst-1-Hematopoietic-Myeloid|SmInt_GW_trimst-1
#                            11                                                         SmInt_Adult-Hematopoietic-Myeloid
#                            12                                                    SmInt_Child04-06-Hematopoietic-Myeloid
#                            13                                               SmInt_Child09-12-Hematopoietic-Myeloid-cDC2
#                            14                                        SmInt_Child09-12-Hematopoietic-Myeloid-Macrophages
#                            15                                        SmInt_Child04-06-Hematopoietic-Myeloid-Macrophages
#                            16                                  SmInt_Child09-12-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            17                                               SmInt_Child04-06-Hematopoietic-Myeloid-cDC2
#                            18                                            SmInt_Pediatric_IBD-Hematopoietic-Myeloid-cDC2
#                            19                        SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-cDC2|SmInt_GW_trimst-1.5
#                            20                                                    SmInt_Child09-12-Hematopoietic-Myeloid
#                            21                                  SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            22           SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1.5
#                            23                     SmInt_GW_trimst-1-Hematopoietic-Myeloid-Macrophages|SmInt_GW_trimst-1
#                            24               SmInt_GW_trimst-1-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1
# 23                         0                         SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-1.5
#                            1                             SmInt_GW_trimst-2-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-2
#                            2                                           SmInt_Child04-06-Hematopoietic-T_cells-TRGV4_gdT
# 6                          0                                                SmInt_Adult-Hematopoietic-T_cells-TRGV2_gdT
#                            1                                  SmInt_GW_trimst-2-Hematopoietic-T_cells|SmInt_GW_trimst-2
#                            2                        SmInt_GW_trimst-2-Hematopoietic-T_cells-NK_T_cell|SmInt_GW_trimst-2
#                            3                          SmInt_GW_trimst-2-Hematopoietic-T_cells-NK_cell|SmInt_GW_trimst-2
#                            4                      SmInt_GW_trimst-1.5-Hematopoietic-T_cells-NK_cell|SmInt_GW_trimst-1.5
#                            5                          SmInt_GW_trimst-1-Hematopoietic-T_cells-NK_cell|SmInt_GW_trimst-1
# 11                         0                        SmInt_GW_trimst-1-Hematopoietic-Myeloid-Monocytes|SmInt_GW_trimst-1
#                            1                                           SmInt_Child04-06-Hematopoietic-Myeloid-Monocytes
#                            2                             SmInt_GW_trimst-1-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-1
#                            3                    SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-Monocytes|SmInt_GW_trimst-1.5
#                            4                        SmInt_GW_trimst-2-Hematopoietic-Myeloid-Monocytes|SmInt_GW_trimst-2
#                            5                                      SmInt_GW_trimst-1.5-Hematopoietic|SmInt_GW_trimst-1.5
#                            6                              SmInt_GW_trimst-1.5-Hematopoietic-Myeloid|SmInt_GW_trimst-1.5
# 18                         0                                                      SmInt_Child09-12-Mesenchymal-myocytic
#                            1                                        SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
#                            2                                     SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
#                            3                                                      SmInt_Child04-06-Mesenchymal-myocytic
#                            4                                                   SmInt_Pediatric_IBD-Mesenchymal-myocytic
#                            5                                        SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
#                            6                                   SmInt_GW_trimst-2-Mesenchymal-myocytic|SmInt_GW_trimst-2
#                            7                                    SmInt_Adult-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            8                                                           SmInt_Adult-Mesenchymal-myocytic
#                            9                      SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-2
#                            10                 SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1.5
#                            11               SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-2
#                            12                     SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1
#                            13                                  SmInt_GW_trimst-1-Mesenchymal-myocytic|SmInt_GW_trimst-1
#                            14                              SmInt_GW_trimst-1.5-Mesenchymal-myocytic|SmInt_GW_trimst-1.5
#                            15                           SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            16                              SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            17               SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-1
# 4                          0                            SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
# 3                          0                                               SmInt_Child04-06-Endothelial-blood_vessel_EC
#                            1                                            SmInt_Pediatric_IBD-Endothelial-blood_vessel_EC
#                            2                                                            SmInt_Pediatric_IBD-Endothelial
#                            3                            SmInt_GW_trimst-2-Endothelial-blood_vessel_EC|SmInt_GW_trimst-2
#                            4                                                               SmInt_Child04-06-Endothelial
#                            5                                 SmInt_Adult-Endothelial-blood_vessel_EC-arterial_capillary
#                            6                         SmInt_Pediatric_IBD-Endothelial-blood_vessel_EC-arterial_capillary
#                            7      SmInt_GW_trimst-1.5-Endothelial-blood_vessel_EC-Fetal_arterial_EC|SmInt_GW_trimst-1.5
# 9                          0                            SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            1                                                      SmInt_Child09-12-Mesenchymal-myocytic
#                            2                               SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            3                               SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            4                                    SmInt_Adult-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            5                                                           SmInt_Adult-Mesenchymal-myocytic
#                            6            SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-1.5
#                            7                SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-2
#                            8                      SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-2
#                            9                                        SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
#                            10                                    SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
#                            11                                                         SmInt_Adult-Mesenchymal-Pericytes
#                            12                                                     SmInt_Child04-06-Mesenchymal-myocytic
#                            13                                  SmInt_GW_trimst-2-Mesenchymal-myocytic|SmInt_GW_trimst-2
#                            14                                                  SmInt_Pediatric_IBD-Mesenchymal-myocytic
#                            15                             SmInt_Adult-Mesenchymal-Pericytes-Contractile_pericyte_(PLN+)
#                            16                     SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1
#                            17                                  SmInt_GW_trimst-1-Mesenchymal-myocytic|SmInt_GW_trimst-1
#                            18               SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-1
#                            19                              SmInt_GW_trimst-1.5-Mesenchymal-myocytic|SmInt_GW_trimst-1.5
# 26                         0                                     SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
#                            1                                   SmInt_GW_trimst-2-Mesenchymal-myocytic|SmInt_GW_trimst-2
#                            2                                                   SmInt_Pediatric_IBD-Mesenchymal-myocytic
#                            3                                                      SmInt_Child09-12-Mesenchymal-myocytic
#                            4                SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-2
#                            5                      SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-2
#                            6                                        SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
#                            7                                                      SmInt_Child04-06-Mesenchymal-myocytic
#                            8                               SmInt_GW_trimst-1.5-Mesenchymal-myocytic|SmInt_GW_trimst-1.5
#                            9                                        SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
#                            10                                  SmInt_GW_trimst-1-Mesenchymal-myocytic|SmInt_GW_trimst-1
#                            11                                   SmInt_Adult-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            12                                                          SmInt_Adult-Mesenchymal-myocytic
#                            13           SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-1.5
#                            14                     SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1
#                            15                 SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1.5
# 32                         0                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgA_plasma_cell
#                            1                                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells
#                            2                                SmInt_Child09-12-Hematopoietic-Plasma_cells-IgA_plasma_cell
#                            3                                                SmInt_Child09-12-Hematopoietic-Plasma_cells
#                            4                             SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            5                                SmInt_Child09-12-Hematopoietic-Plasma_cells-IgG_plasma_cell
#                            6                                                SmInt_Child04-06-Hematopoietic-Plasma_cells
# 25                         0                       SmInt_Child04-06-Hematopoietic-Myeloid-MMP9+_Inflammatory_macrophage
#                            1                    SmInt_Pediatric_IBD-Hematopoietic-Myeloid-MMP9+_Inflammatory_macrophage
#                            2                                                  SmInt_Pediatric_IBD-Hematopoietic-Myeloid
#                            3                       SmInt_Child09-12-Hematopoietic-Myeloid-MMP9+_Inflammatory_macrophage
#                            4                                SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            5                                                     SmInt_Child04-06-Hematopoietic-Myeloid
#                            6                                                     SmInt_Child09-12-Hematopoietic-Myeloid
#                            7                                   SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            8                                      SmInt_Pediatric_IBD-Hematopoietic-Myeloid-Macrophages
# 30                         0      SmInt_GW_trimst-2-Mesenchymal-Pericytes-Contractile_pericyte_(PLN+)|SmInt_GW_trimst-2
#                            1                                                          SmInt_Adult-Mesenchymal-Pericytes
#                            2                              SmInt_Adult-Mesenchymal-Pericytes-Contractile_pericyte_(PLN+)
#                            3                              SmInt_GW_trimst-1.5-Mesenchymal-Pericytes|SmInt_GW_trimst-1.5
#                            4                      SmInt_Pediatric_IBD-Mesenchymal-Pericytes-Contractile_pericyte_(PLN+)
# 22                         0                SmInt_GW_trimst-1-Mesenchymal-Pericytes-Immature_pericyte|SmInt_GW_trimst-1
#                            1                                                  SmInt_Pediatric_IBD-Mesenchymal-Pericytes
#                            2                                         SmInt_Pediatric_IBD-Mesenchymal-Pericytes-Pericyte
#                            3                                            SmInt_Child04-06-Mesenchymal-Pericytes-Pericyte
#                            4                                                     SmInt_Child04-06-Mesenchymal-Pericytes
#                            5                SmInt_GW_trimst-2-Mesenchymal-Pericytes-Immature_pericyte|SmInt_GW_trimst-2
#                            6            SmInt_GW_trimst-1.5-Mesenchymal-Pericytes-Immature_pericyte|SmInt_GW_trimst-1.5
#                            7                              SmInt_GW_trimst-1.5-Mesenchymal-Pericytes|SmInt_GW_trimst-1.5
#                            8                                  SmInt_GW_trimst-1-Mesenchymal-Pericytes|SmInt_GW_trimst-1
#                            9                                  SmInt_GW_trimst-2-Mesenchymal-Pericytes|SmInt_GW_trimst-2
#                            10             SmInt_GW_trimst-1-Mesenchymal-Pericytes-angiogenic_pericyte|SmInt_GW_trimst-1
#                            11             SmInt_GW_trimst-2-Mesenchymal-Pericytes-angiogenic_pericyte|SmInt_GW_trimst-2
#                            12         SmInt_GW_trimst-1.5-Mesenchymal-Pericytes-angiogenic_pericyte|SmInt_GW_trimst-1.5
#                            13                                           SmInt_Child09-12-Mesenchymal-Pericytes-Pericyte
#                            14                                                    SmInt_Child09-12-Mesenchymal-Pericytes
# 10                         0                                SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            1                SmInt_GW_trimst-2-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-2
#                            2                                   SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
#                            3            SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1.5
#                            4                SmInt_GW_trimst-1-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1
#                            5                                              SmInt_Adult-Hematopoietic-Myeloid-Macrophages
# 24                         0                            SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
#                            1                                                       SmInt_Adult-Mesenchymal-fibroblastic
# 33                         0                      SmInt_Pediatric_IBD-Mesenchymal-Pericytes-Contractile_pericyte_(PLN+)
#                            1                         SmInt_Child04-06-Mesenchymal-Pericytes-Contractile_pericyte_(PLN+)
#                            2                            SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            3                                             SmInt_Adult-Mesenchymal-myocytic-myofibroblast
#                            4                                                      SmInt_Child09-12-Mesenchymal-myocytic
#                            5                               SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            6                                        SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
# 7                          0                      SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-2
#                            1                                     SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
#                            2                                                   SmInt_Pediatric_IBD-Mesenchymal-myocytic
#                            3                                   SmInt_GW_trimst-2-Mesenchymal-myocytic|SmInt_GW_trimst-2
#                            4                                                      SmInt_Child09-12-Mesenchymal-myocytic
#                            5                                    SmInt_Adult-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            6                                                           SmInt_Adult-Mesenchymal-myocytic
#                            7                SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-2
#                            8                                        SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
#                            9                                                      SmInt_Child04-06-Mesenchymal-myocytic
#                            10                                  SmInt_GW_trimst-1-Mesenchymal-myocytic|SmInt_GW_trimst-1
#                            11                     SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1
#                            12                              SmInt_GW_trimst-1.5-Mesenchymal-myocytic|SmInt_GW_trimst-1.5
#                            13                 SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1.5
#                            14                                       SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
#                            15                           SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            16                              SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 1                          0                      SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-2
#                            1                SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-2
#                            2                                     SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
#                            3                                   SmInt_GW_trimst-2-Mesenchymal-myocytic|SmInt_GW_trimst-2
#                            4                                                   SmInt_Pediatric_IBD-Mesenchymal-myocytic
#                            5                               SmInt_GW_trimst-1.5-Mesenchymal-myocytic|SmInt_GW_trimst-1.5
#                            6                                                      SmInt_Child09-12-Mesenchymal-myocytic
#                            7                                    SmInt_Adult-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#                            8                                                           SmInt_Adult-Mesenchymal-myocytic
#                            9                                        SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
#                            10                                                     SmInt_Child04-06-Mesenchymal-myocytic
#                            11                     SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1
#                            12                                  SmInt_GW_trimst-1-Mesenchymal-myocytic|SmInt_GW_trimst-1
#                            13                 SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1.5
#                            14                                       SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
#                            15           SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-1.5
# 34                         0                                Enterocyte-C_02|Enterocyte / shred on cell type and cluster
#                            1                                      SmInt_Child09-12-Epithelial-mature_enterocytic-Paneth
#
#                                 Marker Matches  \
# leiden_res1pt5_dist0_npc30 Rank
# 16                         0            7 / 17
#                            1            6 / 17
#                            2            6 / 17
#                            3            6 / 17
#                            4            6 / 17
#                            5            5 / 17
#                            6            5 / 17
#                            7            5 / 17
#                            8            5 / 17
#                            9            5 / 17
# 0                          0            8 / 20
#                            1            8 / 20
#                            2            7 / 20
#                            3            7 / 20
#                            4            7 / 20
#                            5            5 / 20
#                            6            5 / 20
#                            7            5 / 20
# 2                          0           12 / 20
#                            1           12 / 20
#                            2           12 / 20
# 20                         0           14 / 20
#                            1           13 / 20
#                            2           12 / 20
#                            3           12 / 20
#                            4           12 / 20
#                            5           11 / 20
#                            6           11 / 20
#                            7           11 / 20
#                            8           11 / 20
#                            9           10 / 20
#                            10          10 / 20
#                            11          10 / 20
#                            12          10 / 20
#                            13          10 / 20
#                            14          10 / 20
#                            15          10 / 20
#                            16           9 / 20
#                            17           9 / 20
#                            18           9 / 20
#                            19           9 / 20
#                            20           9 / 20
#                            21           9 / 20
#                            22           8 / 20
#                            23           8 / 20
#                            24           7 / 20
#                            25           7 / 20
# 12                         0            5 / 20
#                            1            5 / 20
#                            2            5 / 20
#                            3            5 / 20
#                            4            5 / 20
#                            5            5 / 20
#                            6            5 / 20
#                            7            5 / 20
#                            8            4 / 20
#                            9            4 / 20
#                            10           4 / 20
#                            11           4 / 20
#                            12           4 / 20
#                            13           4 / 20
#                            14           4 / 20
#                            15           4 / 20
#                            16           4 / 20
#                            17           4 / 20
#                            18           4 / 20
#                            19           4 / 20
#                            20           4 / 20
#                            21           4 / 20
#                            22           4 / 20
#                            23           4 / 20
#                            24           4 / 20
# 19                         0             4 / 6
#                            1             4 / 6
#                            2             4 / 6
#                            3             4 / 6
#                            4             4 / 6
#                            5             4 / 6
#                            6             4 / 6
#                            7             4 / 6
# 8                          0           18 / 20
#                            1           17 / 20
#                            2           16 / 20
#                            3           16 / 20
#                            4           16 / 20
#                            5           14 / 20
# 28                         0           11 / 20
#                            1           11 / 20
#                            2            8 / 20
#                            3            8 / 20
#                            4            7 / 20
# 14                         0           10 / 20
#                            1           10 / 20
#                            2            8 / 20
#                            3            6 / 20
#                            4            6 / 20
# 5                          0            8 / 20
#                            1            8 / 20
#                            2            7 / 20
#                            3            7 / 20
#                            4            7 / 20
#                            5            5 / 20
#                            6            5 / 20
#                            7            5 / 20
# 21                         0            8 / 14
#                            1            7 / 14
#                            2            6 / 14
#                            3            6 / 14
#                            4            6 / 14
# 17                         0            8 / 20
#                            1            8 / 20
#                            2            8 / 20
#                            3            8 / 20
#                            4            7 / 20
#                            5            7 / 20
#                            6            7 / 20
#                            7            7 / 20
#                            8            7 / 20
#                            9            7 / 20
#                            10           7 / 20
#                            11           7 / 20
#                            12           7 / 20
#                            13           7 / 20
#                            14           6 / 20
#                            15           6 / 20
#                            16           6 / 20
#                            17           6 / 20
#                            18           6 / 20
#                            19           6 / 20
# 29                         0           13 / 20
#                            1           13 / 20
#                            2           11 / 20
#                            3           11 / 20
# 13                         0           10 / 20
#                            1           10 / 20
#                            2           10 / 20
#                            3           10 / 20
#                            4           10 / 20
#                            5            9 / 20
# 15                         0           15 / 20
#                            1           14 / 20
#                            2           14 / 20
#                            3           13 / 20
# ...
# 29                         0     7.910828e-24  7.893008e-23      9.583098e-23
#                            1     7.910828e-24  7.893008e-23      9.583098e-23
#                            2     1.250546e-19  1.247729e-18      6.627893e-18
#                            3     1.412695e-19  1.409513e-18      1.274967e-17
# 13                         0     3.612103e-17  3.596694e-16      1.331006e-15
#                            1     4.388036e-17  4.369317e-16      3.206157e-15
#                            2     4.388036e-17  4.369317e-16      3.378788e-15
#                            3     4.388036e-17  4.369317e-16      3.378788e-15
#                            4     4.814616e-17  4.794078e-16      3.947985e-15
#                            5     2.996625e-15  2.983841e-14      2.936692e-13
# 15                         0     4.337997e-29  4.264082e-28      3.904197e-28
#                            1     9.940137e-27  9.770766e-26      2.063062e-25
#                            2     9.940137e-27  9.770766e-26      2.385633e-25
#                            3     1.933304e-24  1.900362e-23      7.715876e-23
#                            4     1.933304e-24  1.900362e-23      8.265828e-23
#                            5     1.933304e-24  1.900362e-23      8.265828e-23
#                            6     1.933304e-24  1.900362e-23      8.851753e-23
#                            7     1.933304e-24  1.900362e-23      9.475794e-23
#                            8     1.933304e-24  1.900362e-23      9.475794e-23
#                            9     1.933304e-24  1.900362e-23      1.014021e-22
#                            10    1.933304e-24  1.900362e-23      1.014021e-22
#                            11    1.933304e-24  1.900362e-23      1.014021e-22
#                            12    1.933304e-24  1.900362e-23      1.084738e-22
#                            13    1.603270e-22  1.575952e-21      1.010060e-20
#                            14    1.912644e-22  1.880054e-21      1.243219e-20
#                            15    1.912644e-22  1.880054e-21      1.243219e-20
#                            16    2.681497e-22  2.635807e-21      2.756953e-20
#                            17    2.681497e-22  2.635807e-21      2.756953e-20
#                            18    2.681497e-22  2.635807e-21      3.132545e-20
#                            19    2.681497e-22  2.635807e-21      3.132545e-20
#                            20    2.681497e-22  2.635807e-21      3.337416e-20
#                            21    2.681497e-22  2.635807e-21      3.337416e-20
#                            22    2.681497e-22  2.635807e-21      3.337416e-20
#                            23    2.681497e-22  2.635807e-21      3.554496e-20
#                            24    2.681497e-22  2.635807e-21      3.554496e-20
# 23                         0     4.405037e-03  2.858590e-02      1.000000e+00
#                            1     4.405037e-03  2.858590e-02      1.000000e+00
#                            2     4.405037e-03  2.858590e-02      1.000000e+00
# 6                          0     2.604962e-32  2.574295e-31      3.153898e-31
#                            1     2.616752e-32  2.585946e-31      5.233504e-31
#                            2     5.964255e-30  5.894041e-29      2.365527e-28
#                            3     5.964255e-30  5.894041e-29      2.776830e-28
#                            4     8.915973e-28  8.811010e-27      6.419501e-26
#                            5     1.519638e-27  1.501748e-26      1.393381e-25
# 11                         0     4.720807e-11  4.593586e-10      7.359226e-10
#                            1     1.122165e-09  1.091923e-08      9.874856e-08
#                            2     1.122165e-09  1.091923e-08      1.164654e-07
#                            3     1.122165e-09  1.091923e-08      1.456467e-07
#                            4     1.122165e-09  1.091923e-08      1.502723e-07
#                            5     1.122165e-09  1.091923e-08      1.648887e-07
#                            6     1.122165e-09  1.091923e-08      1.700158e-07
# 18                         0     3.743791e-35  3.542699e-34      3.743791e-35
#                            1     3.818140e-35  3.613054e-34      2.092315e-34
#                            2     3.818140e-35  3.613054e-34      2.092315e-34
#                            3     3.818140e-35  3.613054e-34      2.290884e-34
#                            4     3.818140e-35  3.613054e-34      2.290884e-34
#                            5     6.778215e-33  6.414133e-32      5.422572e-32
#                            6     2.230248e-32  2.110453e-31      2.459136e-31
#                            7     8.816634e-30  8.343061e-29      1.322495e-28
#                            8     1.053304e-29  9.967273e-29      1.685287e-28
#                            9     1.073846e-29  1.016166e-28      1.825539e-28
#                            10    1.088193e-29  1.029742e-28      2.502843e-28
#                            11    2.214535e-27  2.095584e-26      1.146412e-25
#                            12    2.214535e-27  2.095584e-26      1.328721e-25
#                            13    2.214535e-27  2.095584e-26      1.328721e-25
#                            14    2.214535e-27  2.095584e-26      1.328721e-25
#                            15    1.466759e-25  1.387974e-24      9.827288e-24
#                            16    3.874882e-25  3.666748e-24      2.828664e-23
#                            17    6.231276e-25  5.896572e-24      6.566455e-23
# 4                          0     9.988296e-19  9.842419e-18      1.498244e-17
# 3                          0     5.820011e-19  5.804344e-18      1.507357e-17
#                            1     5.227411e-17  5.213339e-16      4.221978e-15
#                            2     5.227411e-17  5.213339e-16      4.221978e-15
#                            3     5.227411e-17  5.213339e-16      4.221978e-15
#                            4     5.227411e-17  5.213339e-16      4.221978e-15
#                            5     5.227411e-17  5.213339e-16      4.221978e-15
#                            6     5.227411e-17  5.213339e-16      4.221978e-15
#                            7     4.957632e-15  4.944287e-14      6.943265e-13
# 9                          0     3.506620e-15  3.337110e-14      1.224369e-13
#                            1     3.506620e-15  3.337110e-14      1.621840e-13
#                            2     3.506620e-15  3.337110e-14      1.698030e-13
#                            3     3.506620e-15  3.337110e-14      2.324769e-13
#                            4     3.506620e-15  3.337110e-14      3.014330e-13
#                            5     3.506620e-15  3.337110e-14      3.421738e-13
#                            6     3.506620e-15  3.337110e-14      3.421738e-13
#                            7     3.506620e-15  3.337110e-14      3.567843e-13
#                            8     3.506620e-15  3.337110e-14      3.567843e-13
#                            9     3.506620e-15  3.337110e-14      3.567843e-13
#                            10    3.506620e-15  3.337110e-14      3.567843e-13
#                            11    3.506620e-15  3.337110e-14      3.719376e-13
#                            12    3.506620e-15  3.337110e-14      3.719376e-13
#                            13    3.506620e-15  3.337110e-14      3.719376e-13
#                            14    3.506620e-15  3.337110e-14      3.719376e-13
#                            15    3.506620e-15  3.337110e-14      3.719376e-13
#                            16    3.506620e-15  3.337110e-14      3.876506e-13
#                            17    3.506620e-15  3.337110e-14      3.876506e-13
#                            18    3.506620e-15  3.337110e-14      3.876506e-13
#                            19    3.506620e-15  3.337110e-14      3.876506e-13
# 26                         0     5.576165e-35  5.335882e-34      2.326821e-34
#                            1     5.576165e-35  5.335882e-34      2.547645e-34
#                            2     5.576165e-35  5.335882e-34      2.547645e-34
#                            3     8.330891e-33  7.971904e-32      4.998535e-32
#                            4     1.417265e-32  1.356193e-31      2.511718e-31
#                            5     1.417265e-32  1.356193e-31      2.511718e-31
#                            6     1.417265e-32  1.356193e-31      2.511718e-31
#                            7     1.417265e-32  1.356193e-31      2.734756e-31
#                            8     1.417265e-32  1.356193e-31      2.976256e-31
#                            9     2.140558e-30  2.048319e-29      5.351394e-29
#                            10    4.282094e-30  4.097574e-29      2.379084e-28
#                            11    1.210948e-27  1.158767e-26      9.445392e-26
#                            12    1.408948e-27  1.348235e-26      1.183516e-25
#                            13    1.408948e-27  1.348235e-26      1.183516e-25
#                            14    1.523344e-27  1.457701e-26      1.477643e-25
#                            15    1.656273e-27  1.584902e-26      1.709981e-25
# 32                         0     8.757736e-12  8.560357e-11      7.449225e-11
#                            1     8.757736e-12  8.560357e-11      8.860413e-11
#                            2     4.684660e-10  4.579078e-09      9.281933e-09
#                            3     4.684660e-10  4.579078e-09      1.004100e-08
#                            4     4.684660e-10  4.579078e-09      1.217481e-08
#                            5     1.287363e-06  1.258349e-05      1.208752e-04
#                            6     1.287363e-06  1.258349e-05      1.467827e-04
# 25                         0     1.056528e-34  1.036480e-33      1.056528e-34
#                            1     1.621243e-34  1.590480e-33      3.242487e-34
#                            2     2.214057e-29  2.172045e-28      3.542491e-28
#                            3     3.888410e-27  3.814626e-26      6.999138e-26
#                            4     5.086702e-27  4.990180e-26      1.622617e-25
#                            5     5.086702e-27  4.990180e-26      2.176359e-25
#                            6     9.560814e-25  9.379394e-24      8.107312e-23
#                            7     9.560814e-25  9.379394e-24      8.107312e-23
#                            8     9.560814e-25  9.379394e-24      9.294074e-23
# 30                         0     3.906039e-29  3.782922e-28      2.889589e-28
#                            1     9.394353e-27  9.098246e-26      1.541221e-25
#                            2     9.394353e-27  9.098246e-26      1.541221e-25
#                            3     3.342708e-22  3.237347e-21      2.710227e-20
#                            4     3.342708e-22  3.237347e-21      3.075292e-20
# 22                         0     2.396638e-23  2.379667e-22      8.523790e-23
#                            1     2.396638e-23  2.379667e-22      1.120197e-22
#                            2     2.396638e-23  2.379667e-22      1.120197e-22
#                            3     2.396638e-23  2.379667e-22      1.198319e-22
#                            4     2.396638e-23  2.379667e-22      1.198319e-22
#                            5     3.145952e-21  3.123675e-20      3.247020e-20
#                            6     3.145952e-21  3.123675e-20      3.247020e-20
#                            7     3.145952e-21  3.123675e-20      3.460548e-20
#                            8     3.145952e-21  3.123675e-20      3.460548e-20
#                            9     3.422850e-21  3.398611e-20      4.449705e-20
#                            10    1.845806e-19  1.832735e-18      2.584129e-18
#                            11    4.866862e-19  4.832398e-18      1.362721e-17
#                            12    1.990481e-15  1.976386e-14      1.492861e-13
#                            13    4.978631e-15  4.943376e-14      4.082478e-13
#                            14    6.124966e-15  6.081592e-14      5.757468e-13
# 10                         0     4.567080e-32  4.541428e-31      3.653664e-31
#                            1     4.655423e-32  4.629274e-31      5.120965e-31
#                            2     1.367700e-29  1.360018e-28      2.953144e-28
#                            3     3.991515e-27  3.969096e-26      1.854533e-25
#                            4     1.171487e-24  1.164907e-23      9.922892e-23
#                            5     1.171487e-24  1.164907e-23      1.136726e-22
# 24                         0     2.208545e-19  2.186349e-18      1.568067e-17
#                            1     2.208545e-19  2.186349e-18      1.568067e-17
# 33                         0     4.519769e-13  3.914297e-12      1.878855e-11
#                            1     6.978555e-11  6.043701e-10      1.195383e-08
#                            2     6.978555e-11  6.043701e-10      1.347388e-08
#                            3     6.978555e-11  6.043701e-10      1.514472e-08
#                            4     6.978555e-11  6.043701e-10      1.604009e-08
#                            5     6.978555e-11  6.043701e-10      1.650338e-08
#                            6     6.978555e-11  6.043701e-10      1.697730e-08
# 7                          0     3.628719e-35  3.337549e-34      3.628719e-35
#                            1     1.718875e-32  1.580952e-31      1.466526e-31
#                            2     1.718875e-32  1.580952e-31      1.588029e-31
#                            3     1.718875e-32  1.580952e-31      1.588029e-31
#                            4     6.162672e-30  5.668178e-29      6.778939e-29
#                            5     9.150902e-30  8.416631e-29      2.046296e-28
#                            6     9.150902e-30  8.416631e-29      2.564659e-28
#                            7     9.150902e-30  8.416631e-29      2.762917e-28
#                            8     9.150902e-30  8.416631e-29      2.762917e-28
#                            9     9.150902e-30  8.416631e-29      2.975327e-28
#                            10    9.150902e-30  8.416631e-29      3.202816e-28
#                            11    9.150902e-30  8.416631e-29      3.202816e-28
#                            12    9.150902e-30  8.416631e-29      3.202816e-28
#                            13    9.505181e-30  8.742483e-29      3.707021e-28
#                            14    2.373267e-27  2.182836e-26      1.020505e-25
#                            15    6.575161e-25  6.047568e-24      5.128626e-23
#                            16    1.508803e-24  1.387736e-23      1.357922e-22
# 1                          0     6.502806e-32  6.134991e-31      2.195136e-31
#                            1     7.700812e-30  7.265235e-29      1.774261e-28
#                            2     7.700812e-30  7.265235e-29      1.774261e-28
#                            3     7.700812e-30  7.265235e-29      1.921101e-28
#                            4     7.700812e-30  7.265235e-29      1.921101e-28
#                            5     7.700812e-30  7.265235e-29      2.079219e-28
#                            6     8.555650e-28  8.071721e-27      2.737808e-26
#                            7     2.293021e-27  2.163322e-26      8.254875e-26
#                            8     2.306068e-27  2.175631e-26      1.034343e-25
#                            9     2.306068e-27  2.175631e-26      1.114211e-25
#                            10    2.306068e-27  2.175631e-26      1.199771e-25
#                            11    2.306068e-27  2.175631e-26      1.291398e-25
#                            12    2.306068e-27  2.175631e-26      1.291398e-25
#                            13    2.372146e-27  2.237971e-26      1.494452e-25
#                            14    2.717000e-25  2.563320e-24      1.766050e-23
#                            15    6.337431e-25  5.978970e-24      5.196693e-23
# 34                         0     4.386018e-03  3.238413e-02      1.000000e+00
#                            1     4.386018e-03  3.238413e-02      1.000000e+00

# %% [markdown]
# # Quantification

# %% [markdown]
# ## By Markers

# %%
# %%time

outs, failed = {}, []  # hold results
for i, k in enumerate(self.rna.obs[c_t].unique()):
    if tgdf is not None and k in tgdf.reset_index(1).index.values:
        print(f"{'=' * 80}\n{k}\n ({i + 1}/{len(self.rna.obs[c_t].unique())})"
              f"\n{'=' * 80}\n\n{tgdf.loc[k].iloc[:, :3]}\n\n")
    try:
        outs[k] = self.print_markers(
                k, assign, col_cell_type=c_t, lfc_threshold=2,
                count_threshold=count_threshold, p_threshold=1e-15,
                print_threshold=15, n_top_genes=20)
    except Exception as err:
        failed += [(k, err)]
if len(failed) > 0:
    print(f"Failed: {pd.Series(dict(failed))}")
# Out:
# ================================================================================
# 16
#  (1/35)
# ================================================================================
#
#                                                                                   Name  \
# Rank
# 0                                                            SmInt_Adult-Hematopoietic
# 1                       SmInt_GW_trimst-1-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-1
# 2         SmInt_GW_trimst-1-Hematopoietic-T_cells-LTi-like_NCR-_ILC3|SmInt_GW_trimst-1
# 3                                               SmInt_Adult-Hematopoietic-Myeloid-cDC2
# 4                                            SmInt_Pediatric_IBD-Hematopoietic-Myeloid
# 5                       SmInt_GW_trimst-2-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-2
# 6                       SmInt_GW_trimst-2-Hematopoietic-T_cells-ILCP|SmInt_GW_trimst-2
# 7                          SmInt_Child04-06-Hematopoietic-Plasma_cells-IgG_plasma_cell
# 8                       SmInt_GW_trimst-1-Hematopoietic-T_cells-ILCP|SmInt_GW_trimst-1
# 9     SmInt_GW_trimst-1.5-Hematopoietic-T_cells-LTi-like_NCR+_ILC3|SmInt_GW_trimst-1.5
#
#      Marker Matches                                             Genes
# Rank
# 0            7 / 17  [JAML, CXCR4, CD79A, PTPN22, ADAM28, LY9, PRDM1]
# 1            6 / 17          [LST1, IDO1, APOBR, JAML, PTPN22, CXCL9]
# 2            6 / 17           [LST1, APOBR, JAML, CXCR4, PTPN22, LY9]
# 3            6 / 17          [LAMP3, LST1, IDO1, JAML, CXCR4, ADAM28]
# 4            6 / 17          [LST1, IDO1, JAML, PLAUR, CXCL9, CSF2RB]
# 5            5 / 17                  [LST1, IDO1, APOBR, JAML, CXCL9]
# 6            5 / 17                  [LST1, JAML, CXCR4, PTPN22, LY9]
# 7            5 / 17                 [XBP1, RPN2, CD79A, IL5RA, PRDM1]
# 8            5 / 17                  [LST1, JAML, CXCR4, PTPN22, LY9]
# 9            5 / 17                  [LST1, JAML, CXCR4, PTPN22, LY9]
#
#
# ================================================================================
# 0
#  (2/35)
# ================================================================================
#
#                                                                 Name  \
# Rank
# 0     SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgA_plasma_cell
# 1                     SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells
# 2        SmInt_Child09-12-Hematopoietic-Plasma_cells-IgA_plasma_cell
# 3                        SmInt_Child09-12-Hematopoietic-Plasma_cells
# 4     SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgG_plasma_cell
# 5        SmInt_Child04-06-Hematopoietic-Plasma_cells-IgG_plasma_cell
# 6        SmInt_Child09-12-Hematopoietic-Plasma_cells-IgG_plasma_cell
# 7        SmInt_Child04-06-Hematopoietic-Plasma_cells-IgA_plasma_cell
#
#      Marker Matches                                                  Genes
# Rank
# 0            8 / 20  [XBP1, KCNN3, RPN1, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 1            8 / 20  [XBP1, KCNN3, RPN1, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 2            7 / 20    [XBP1, KCNN3, CD79A, ZBTB38, IFNAR2, PRDM1, CSF2RB]
# 3            7 / 20    [XBP1, KCNN3, CD79A, ZBTB38, IFNAR2, PRDM1, CSF2RB]
# 4            7 / 20        [XBP1, KCNN3, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 5            5 / 20                      [XBP1, RPN2, CD79A, IL5RA, PRDM1]
# 6            5 / 20                     [XBP1, RPN2, CD79A, IFNAR2, PRDM1]
# 7            5 / 20                     [XBP1, KCNN3, CD79A, IL5RA, PRDM1]
#
#
# ================================================================================
# 2
#  (3/35)
# ================================================================================
#
#                                                                        Name  \
# Rank
# 0                                SmInt_Child09-12-Hematopoietic-T_cells-Tfh
# 1                             SmInt_Pediatric_IBD-Hematopoietic-T_cells-Tfh
# 2     SmInt_GW_trimst-2-Hematopoietic-T_cells-Activated_T|SmInt_GW_trimst-2
#
#      Marker Matches  \
# Rank
# 0           12 / 20
# 1           12 / 20
# 2           12 / 20
#
#                                                                               Genes
# Rank
# 0       [LBH, CXCR4, KLRB1, ARHGDIB, LTB, CD52, CD3D, IL6ST, TCF7, CD3E, IL7R, CD4]
# 1        [ETS1, KLRB1, ARHGDIB, LTB, CD52, CD3D, TCF7, CD3E, IL7R, CD4, ITPKB, MAF]
# 2     [CD44, ETS1, CXCR4, KLRB1, ARHGDIB, LTB, CD52, CD3D, TCF7, CD3E, IKZF3, IL7R]
#
#
# ================================================================================
# 20
#  (4/35)
# ================================================================================
#
#                                                                                         Name  \
# Rank
# 0                            SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
# 1                         SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
# 2                                    SmInt_Adult-Mesenchymal-fibroblastic-Stromal_1_(CCL11+)
# 3                                                            SmInt_Pediatric_IBD-Mesenchymal
# 4                            SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
# 5         SmInt_GW_trimst-2-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|SmInt_GW_trimst-2
# 6                                               SmInt_Pediatric_IBD-Mesenchymal-fibroblastic
# 7                                                               SmInt_Child04-06-Mesenchymal
# 8                                                               SmInt_Child09-12-Mesenchymal
# 9         SmInt_GW_trimst-1-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|SmInt_GW_trimst-1
# 10                              SmInt_GW_trimst-1-Mesenchymal-fibroblastic|SmInt_GW_trimst-1
# 11                                                 SmInt_Child04-06-Mesenchymal-fibroblastic
# 12                                                 SmInt_Child09-12-Mesenchymal-fibroblastic
# 13                              SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_1_(CCL11+)
# 14                              SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(CCL11+)
# 15                           SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-Stromal_1_(CCL11+)
# 16                                SmInt_Adult-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
# 17    SmInt_GW_trimst-1.5-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|SmInt_GW_trimst-1.5
# 18                              SmInt_GW_trimst-2-Mesenchymal-fibroblastic|SmInt_GW_trimst-2
# 19                                SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
# 20                                SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
# 21                             SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
# 22             SmInt_GW_trimst-2-Mesenchymal-fibroblastic-Stromal_2_(NPY+)|SmInt_GW_trimst-2
# 23                          SmInt_GW_trimst-1.5-Mesenchymal-fibroblastic|SmInt_GW_trimst-1.5
# 24                                       SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
# 25                                         SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-mLTo
#
#      Marker Matches  \
# Rank
# 0           14 / 20
# 1           13 / 20
# 2           12 / 20
# 3           12 / 20
# 4           12 / 20
# 5           11 / 20
# 6           11 / 20
# 7           11 / 20
# 8           11 / 20
# 9           10 / 20
# 10          10 / 20
# 11          10 / 20
# 12          10 / 20
# 13          10 / 20
# 14          10 / 20
# 15          10 / 20
# 16           9 / 20
# 17           9 / 20
# 18           9 / 20
# 19           9 / 20
# 20           9 / 20
# 21           9 / 20
# 22           8 / 20
# 23           8 / 20
# 24           7 / 20
# 25           7 / 20
#
#                                                                                                         Genes
# Rank
# 0     [IGFBP7, ADAMDEC1, PDGFRA, COL4A2, PDPN, CXCL1, CCL2, BMP5, ADAM28, CCL11, IL6ST, CSF1, COL1A1, COL1A2]
# 1           [IGFBP7, ADAMDEC1, PDGFRA, COL4A2, PDPN, CXCL1, CCL2, BMP5, ADAM28, CCL11, IL6ST, COL1A1, COL1A2]
# 2                [COL4A1, IGFBP7, ADAMDEC1, PDGFRA, COL4A2, CXCL1, CCL2, BMP5, ADAM28, CCL11, COL1A1, COL1A2]
# 3                  [COL4A1, IGFBP7, ADAMDEC1, PDGFRA, COL4A2, PDPN, CXCL1, CCL2, BMP5, CCL11, COL1A1, COL1A2]
# 4                  [IGFBP7, ADAMDEC1, PDGFRA, COL4A2, CXCL1, CCL2, BMP5, ADAM28, CCL11, CSF1, COL1A1, COL1A2]
# 5                           [IGFBP7, ADAMDEC1, COL4A2, PDPN, CXCL1, CCL2, BMP5, ADAM28, CSF1, COL1A1, COL1A2]
# 6                          [IGFBP7, ADAMDEC1, PDGFRA, COL4A2, PDPN, CXCL1, CCL2, BMP5, CCL11, COL1A1, COL1A2]
# 7                        [COL4A1, IGFBP7, ADAMDEC1, PDGFRA, COL4A2, CXCL1, CCL2, BMP5, CCL11, COL1A1, COL1A2]
# 8                        [COL4A1, IGFBP7, ADAMDEC1, PDGFRA, COL4A2, CXCL1, CCL2, BMP5, CCL11, COL1A1, COL1A2]
# 9                               [COL4A1, IGFBP7, ADAMDEC1, PDGFRA, CXCL1, CCL2, BMP5, ADAM28, COL1A1, COL1A2]
# 10                                 [COL4A1, IGFBP7, ADAMDEC1, PDGFRA, F3, CCL2, BMP5, ADAM28, COL1A1, COL1A2]
# 11                               [IGFBP7, ADAMDEC1, PDGFRA, COL4A2, CXCL1, CCL2, BMP5, CCL11, COL1A1, COL1A2]
# 12                               [IGFBP7, ADAMDEC1, PDGFRA, COL4A2, CXCL1, CCL2, BMP5, CCL11, COL1A1, COL1A2]
# 13                               [IGFBP7, ADAMDEC1, PDGFRA, CXCL1, CCL2, BMP5, ADAM28, CCL11, COL1A1, COL1A2]
# 14                               [IGFBP7, ADAMDEC1, PDGFRA, CXCL1, CCL2, BMP5, ADAM28, CCL11, COL1A1, COL1A2]
# 15                                [IGFBP7, ADAMDEC1, PDGFRA, CXCL1, CCL2, BMP5, CCL11, IL6ST, COL1A1, COL1A2]
# 16                                     [COL4A1, IGFBP7, ADAMDEC1, COL4A2, CXCL1, BMP5, CCL11, COL1A1, COL1A2]
# 17                                          [IGFBP7, ADAMDEC1, PDGFRA, CXCL1, F3, CCL2, BMP5, ADAM28, COL1A2]
# 18                                       [IGFBP7, ADAMDEC1, PDGFRA, COL4A2, F3, BMP5, ADAM28, COL1A1, COL1A2]
# 19                                           [COL4A1, IGFBP7, PDGFRA, COL4A2, PDPN, F3, BMP5, COL1A1, COL1A2]
# 20                                           [COL4A1, IGFBP7, PDGFRA, COL4A2, PDPN, F3, BMP5, COL1A1, COL1A2]
# 21                                           [COL4A1, IGFBP7, PDGFRA, COL4A2, PDPN, F3, BMP5, COL1A1, COL1A2]
# 22                                               [COL4A1, IGFBP7, ADAMDEC1, PDGFRA, F3, BMP5, ADAM28, COL1A2]
# 23                                               [IGFBP7, ADAMDEC1, PDGFRA, F3, BMP5, ADAM28, COL1A1, COL1A2]
# 24                                                   [COL4A1, IGFBP7, ADAMDEC1, COL4A2, BMP5, COL1A1, COL1A2]
# 25                                                          [IGFBP7, PDPN, CXCL1, CCL2, CSF1, COL1A1, COL1A2]
#
#
# ================================================================================
# 12
#  (5/35)
# ================================================================================
#
#                                                                                      Name  \
# Rank
# 0                                               SmInt_Adult-Epithelial-goblet-Goblet_cell
# 1                                                           SmInt_Adult-Epithelial-goblet
# 2                   SmInt_GW_trimst-1.5-Epithelial-goblet-Goblet_cell|SmInt_GW_trimst-1.5
# 3                       SmInt_GW_trimst-1-Epithelial-goblet-Goblet_cell|SmInt_GW_trimst-1
# 4                                   SmInt_GW_trimst-1-Epithelial-goblet|SmInt_GW_trimst-1
# 5                               SmInt_GW_trimst-1.5-Epithelial-goblet|SmInt_GW_trimst-1.5
# 6                               SmInt_Pediatric_IBD-Epithelial-epithelial_progenitor_cell
# 7                            SmInt_Pediatric_IBD-Epithelial-epithelial_progenitor_cell-TA
# 8                                   SmInt_Child04-06-Epithelial-mature_enterocytic-Paneth
# 9                                SmInt_Pediatric_IBD-Epithelial-goblet-BEST2+_Goblet_cell
# 10           SmInt_GW_trimst-1.5-Epithelial-mature_enterocytic-Paneth|SmInt_GW_trimst-1.5
# 11      SmInt_GW_trimst-1.5-Epithelial-Tuft-related-BEST4+_epithelial|SmInt_GW_trimst-1.5
# 12                        SmInt_GW_trimst-1.5-Epithelial-Tuft-related|SmInt_GW_trimst-1.5
# 13                            SmInt_GW_trimst-1-Epithelial-Tuft-related|SmInt_GW_trimst-1
# 14          SmInt_GW_trimst-1-Epithelial-Tuft-related-BEST4+_epithelial|SmInt_GW_trimst-1
# 15    Enterocyte_Progenitors-C_06|Enterocyte_Progenitors / shred on cell type and cluster
# 16                                      SmInt_Pediatric_IBD-Epithelial-goblet-Goblet_cell
# 17                                 SmInt_Child09-12-Epithelial-epithelial_progenitor_cell
# 18                                                  SmInt_Pediatric_IBD-Epithelial-goblet
# 19                                         SmInt_Child09-12-Epithelial-goblet-Goblet_cell
# 20                                                     SmInt_Child09-12-Epithelial-goblet
# 21                              SmInt_Child09-12-Epithelial-epithelial_progenitor_cell-TA
# 22                           SmInt_Adult-Epithelial-epithelial_progenitor_cell-Stem_cells
# 23                                      SmInt_Adult-Epithelial-epithelial_progenitor_cell
# 24                                   SmInt_Adult-Epithelial-epithelial_progenitor_cell-TA
#
#      Marker Matches                                    Genes
# Rank
# 0            5 / 20  [MUC2, KLK1, FAM3D, SERPINA1, MARCKSL1]
# 1            5 / 20  [MUC2, KLK1, FAM3D, SERPINA1, MARCKSL1]
# 2            5 / 20      [MUC2, KLK1, IRF6, SERPINA1, PLAC8]
# 3            5 / 20      [CCL25, MUC2, KLK1, IRF6, SERPINA1]
# 4            5 / 20      [CCL25, MUC2, KLK1, IRF6, SERPINA1]
# 5            5 / 20      [MUC2, KLK1, IRF6, SERPINA1, PLAC8]
# 6            5 / 20      [CCL25, FAM3D, MYO10, UQCRC1, LCN2]
# 7            5 / 20      [CCL25, FAM3D, MYO10, UQCRC1, LCN2]
# 8            4 / 20              [LYZ, KLK1, SERPINA1, LCN2]
# 9            4 / 20                [MUC2, KLK1, FAM3D, IRF6]
# 10           4 / 20              [LYZ, KLK1, IRF6, SERPINA1]
# 11           4 / 20                [LYZ, KLK1, FAM3D, PLAC8]
# 12           4 / 20                [LYZ, KLK1, FAM3D, PLAC8]
# 13           4 / 20                [LYZ, KLK1, FAM3D, PLAC8]
# 14           4 / 20                [LYZ, KLK1, FAM3D, PLAC8]
# 15           4 / 20             [LYZ, FAM3D, SERPINA1, LCN2]
# 16           4 / 20                [MUC2, KLK1, FAM3D, IRF6]
# 17           4 / 20           [CCL25, MYO10, MARCKSL1, LCN2]
# 18           4 / 20                [MUC2, KLK1, FAM3D, IRF6]
# 19           4 / 20                [MUC2, KLK1, FAM3D, IRF6]
# 20           4 / 20                [MUC2, KLK1, FAM3D, IRF6]
# 21           4 / 20           [CCL25, MYO10, MARCKSL1, LCN2]
# 22           4 / 20           [CCL25, KLK1, MYO10, MARCKSL1]
# 23           4 / 20           [CCL25, KLK1, MYO10, MARCKSL1]
# 24           4 / 20           [CCL25, KLK1, MYO10, MARCKSL1]
#
#
# ================================================================================
# 19
#  (6/35)
# ================================================================================
#
#                                                                               Name  \
# Rank
# 0         SmInt_GW_trimst-2-Hematopoietic-Myeloid-CLC+_Mast_cell|SmInt_GW_trimst-2
# 1              SmInt_GW_trimst-2-Hematopoietic-Myeloid-Mast_cell|SmInt_GW_trimst-2
# 2                                 SmInt_Child09-12-Hematopoietic-Myeloid-Mast_cell
# 3     SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-CLC+_Mast_cell|SmInt_GW_trimst-1.5
# 4                                      SmInt_Adult-Hematopoietic-Myeloid-Mast_cell
# 5                                 SmInt_Child04-06-Hematopoietic-Myeloid-Mast_cell
# 6                              SmInt_Pediatric_IBD-Hematopoietic-Myeloid-Mast_cell
# 7                                 SmInt_Adult-Epithelial-mature_enterocytic-Paneth
#
#      Marker Matches                      Genes
# Rank
# 0             4 / 6  [KIT, TPSAB1, CPA3, CMA1]
# 1             4 / 6  [KIT, TPSAB1, CPA3, CMA1]
# 2             4 / 6  [KIT, TPSAB1, CPA3, CMA1]
# 3             4 / 6  [KIT, TPSAB1, CPA3, CMA1]
# 4             4 / 6  [KIT, TPSAB1, CPA3, CMA1]
# 5             4 / 6  [KIT, TPSAB1, CPA3, CMA1]
# 6             4 / 6  [KIT, TPSAB1, CPA3, CMA1]
# 7             4 / 6  [KIT, TPSAB1, CPA3, CMA1]
#
#
# ================================================================================
# 8
#  (7/35)
# ================================================================================
#
#                                                                                  Name  \
# Rank
# 0                         SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 1         SmInt_GW_trimst-2-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-2
# 2                            SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 3     SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1.5
# 4         SmInt_GW_trimst-1-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1
# 5                                 SmInt_Adult-Hematopoietic-Myeloid-LYVE1+_Macrophage
#
#      Marker Matches  \
# Rank
# 0           18 / 20
# 1           17 / 20
# 2           16 / 20
# 3           16 / 20
# 4           16 / 20
# 5           14 / 20
#
#                                                                                                                   Genes
# Rank
# 0     [SPI1, CD14, DAB2, IL10RA, LYZ, AIF1, MRC1, FCGRT, HCK, MAFB, PLTP, CD163, CD4, CSF1R, APOE, MAF, CSF2RA, FCER1G]
# 1        [SPI1, CD14, DAB2, IL10RA, AIF1, MRC1, LYVE1, HCK, MAFB, PLTP, RNASE1, CD163, CD4, CSF1R, MAF, CSF2RA, FCER1G]
# 2                [CD14, DAB2, IL10RA, LYZ, AIF1, MRC1, FCGRT, HCK, MAFB, PLTP, CD163, CD4, CSF1R, APOE, CSF2RA, FCER1G]
# 3              [SPI1, CD14, DAB2, IL10RA, AIF1, MRC1, LYVE1, HCK, MAFB, RNASE1, CD163, CD4, CSF1R, MAF, CSF2RA, FCER1G]
# 4              [SPI1, CD14, DAB2, IL10RA, AIF1, MRC1, LYVE1, HCK, MAFB, RNASE1, CD163, CD4, CSF1R, MAF, CSF2RA, FCER1G]
# 5                         [SPI1, CD14, IL10RA, AIF1, MRC1, LYVE1, HCK, MAFB, RNASE1, CD163, CD4, CSF1R, CSF2RA, FCER1G]
#
#
# ================================================================================
# 28
#  (8/35)
# ================================================================================
#
#                                                                    Name  \
# Rank
# 0                            SmInt_Child04-06-Hematopoietic-Myeloid-pDC
# 1                         SmInt_Pediatric_IBD-Hematopoietic-Myeloid-pDC
# 2         SmInt_GW_trimst-1-Hematopoietic-Myeloid-pDC|SmInt_GW_trimst-1
# 3         SmInt_GW_trimst-2-Hematopoietic-Myeloid-pDC|SmInt_GW_trimst-2
# 4     SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-pDC|SmInt_GW_trimst-1.5
#
#      Marker Matches  \
# Rank
# 0           11 / 20
# 1           11 / 20
# 2            8 / 20
# 3            8 / 20
# 4            7 / 20
#
#                                                                                    Genes
# Rank
# 0     [IRF8, PPP1R14B, JAML, IL3RA, PLAC8, SERPINF1, GPR183, CD4, GZMB, RNASET2, CSF2RB]
# 1     [IRF8, PPP1R14B, JAML, IL3RA, PLAC8, SERPINF1, GPR183, CD4, GZMB, RNASET2, CSF2RB]
# 2                              [IRF8, JAML, IL3RA, CXCR4, PLAC8, SERPINF1, GPR183, GZMB]
# 3                              [IRF8, JAML, IL3RA, ABCA7, PLAC8, SERPINF1, GPR183, GZMB]
# 4                                      [IRF8, IL3RA, ABCA7, CXCR4, PLAC8, GZMB, RNASET2]
#
#
# ================================================================================
# 14
#  (9/35)
# ================================================================================
#
#                                                                 Name  \
# Rank
# 0           SmInt_Pediatric_IBD-Hematopoietic-B_cells-Cycling_B_cell
# 1              SmInt_Child04-06-Hematopoietic-B_cells-Cycling_B_cell
# 2              SmInt_Child09-12-Hematopoietic-B_cells-Cycling_B_cell
# 3     SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgA_plasma_cell
# 4                     SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells
#
#      Marker Matches  \
# Rank
# 0           10 / 20
# 1           10 / 20
# 2            8 / 20
# 3            6 / 20
# 4            6 / 20
#
#                                                                        Genes
# Rank
# 0     [H2AX, SNRPD1, TUBA1B, HMGB1, TK1, HMGB2, SNRPG, RANBP1, TOP2A, TFDP1]
# 1     [H2AX, SNRPD1, TUBA1B, HMGB1, TK1, HMGB2, SNRPG, RANBP1, TOP2A, TFDP1]
# 2                   [H2AX, SNRPD1, TUBA1B, TK1, HMGB2, RANBP1, TOP2A, TFDP1]
# 3                                    [XBP1, RPN1, RPN2, ATF4, IFNAR2, PRDM1]
# 4                                    [XBP1, RPN1, RPN2, ATF4, IFNAR2, PRDM1]
#
#
# ================================================================================
# 5
#  (12/35)
# ================================================================================
#
#                                                                 Name  \
# Rank
# 0     SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgA_plasma_cell
# 1                     SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells
# 2        SmInt_Child09-12-Hematopoietic-Plasma_cells-IgA_plasma_cell
# 3                        SmInt_Child09-12-Hematopoietic-Plasma_cells
# 4     SmInt_Pediatric_IBD-Hematopoietic-Plasma_cells-IgG_plasma_cell
# 5        SmInt_Child04-06-Hematopoietic-Plasma_cells-IgG_plasma_cell
# 6        SmInt_Child09-12-Hematopoietic-Plasma_cells-IgG_plasma_cell
# 7        SmInt_Child04-06-Hematopoietic-Plasma_cells-IgA_plasma_cell
#
#      Marker Matches                                                  Genes
# Rank
# 0            8 / 20  [XBP1, KCNN3, RPN1, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 1            8 / 20  [XBP1, KCNN3, RPN1, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 2            7 / 20    [XBP1, KCNN3, CD79A, ZBTB38, IFNAR2, PRDM1, CSF2RB]
# 3            7 / 20    [XBP1, KCNN3, CD79A, ZBTB38, IFNAR2, PRDM1, CSF2RB]
# 4            7 / 20        [XBP1, KCNN3, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 5            5 / 20                      [XBP1, RPN2, CD79A, IL5RA, PRDM1]
# 6            5 / 20                     [XBP1, RPN2, CD79A, IFNAR2, PRDM1]
# 7            5 / 20                     [XBP1, KCNN3, CD79A, IL5RA, PRDM1]
#
#
# ================================================================================
# 21
#  (13/35)
# ================================================================================
#
#                                                                      Name  \
# Rank
# 0                        SmInt_Child09-12-Hematopoietic-Myeloid-Mast_cell
# 1                        SmInt_Child04-06-Hematopoietic-Myeloid-Mast_cell
# 2     SmInt_GW_trimst-2-Hematopoietic-Myeloid-Mast_cell|SmInt_GW_trimst-2
# 3                             SmInt_Adult-Hematopoietic-Myeloid-Mast_cell
# 4                     SmInt_Pediatric_IBD-Hematopoietic-Myeloid-Mast_cell
#
#      Marker Matches                                                  Genes
# Rank
# 0            8 / 14  [CD44, KIT, TPSAB1, FOXP1, CPA3, MACIR, FCER1G, CMA1]
# 1            7 / 14          [CD44, KIT, TPSAB1, CPA3, CSF1, FCER1G, CMA1]
# 2            6 / 14                [CD44, KIT, TPSAB1, CPA3, FCER1G, CMA1]
# 3            6 / 14                [CD44, KIT, TPSAB1, CPA3, FCER1G, CMA1]
# 4            6 / 14                [CD44, KIT, TPSAB1, CPA3, FCER1G, CMA1]
#
#
# ================================================================================
# 17
#  (14/35)
# ================================================================================
#
#                                                                                     Name  \
# Rank
# 0                                              SmInt_Pediatric_IBD-Mesenchymal-Pericytes
# 1                                     SmInt_Pediatric_IBD-Mesenchymal-Pericytes-Pericyte
# 2                                                 SmInt_Child04-06-Mesenchymal-Pericytes
# 3                                        SmInt_Child04-06-Mesenchymal-Pericytes-Pericyte
# 4            SmInt_GW_trimst-1-Mesenchymal-Pericytes-Immature_pericyte|SmInt_GW_trimst-1
# 5     SmInt_GW_trimst-2-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|SmInt_GW_trimst-2
# 6                             SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
# 7                             SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
# 8                          SmInt_Pediatric_IBD-Mesenchymal-fibroblastic-Stromal_2_(NPY+)
# 9                                                        SmInt_Pediatric_IBD-Mesenchymal
# 10                       SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
# 11                                                          SmInt_Child04-06-Mesenchymal
# 12                                                          SmInt_Child09-12-Mesenchymal
# 13                       SmInt_Child09-12-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
# 14                                     SmInt_Child04-06-Neuronal-Glial_mature-Adult_Glia
# 15                                                             SmInt_Child04-06-Neuronal
# 16                                                SmInt_Child04-06-Neuronal-Glial_mature
# 17                             SmInt_GW_trimst-1-Mesenchymal-Pericytes|SmInt_GW_trimst-1
# 18                                SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
# 19                                   SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
#
#      Marker Matches  \
# Rank
# 0            8 / 20
# 1            8 / 20
# 2            8 / 20
# 3            8 / 20
# 4            7 / 20
# 5            7 / 20
# 6            7 / 20
# 7            7 / 20
# 8            7 / 20
# 9            7 / 20
# 10           7 / 20
# 11           7 / 20
# 12           7 / 20
# 13           7 / 20
# 14           6 / 20
# 15           6 / 20
# 16           6 / 20
# 17           6 / 20
# 18           6 / 20
# 19           6 / 20
#
#                                                              Genes
# Rank
# 0     [COL4A1, IGFBP7, COL4A2, IFITM3, DLC1, COL1A1, GPX3, COL1A2]
# 1     [COL4A1, IGFBP7, COL4A2, IFITM3, DLC1, COL1A1, GPX3, COL1A2]
# 2     [COL4A1, IGFBP7, COL4A2, IFITM3, DLC1, COL1A1, GPX3, COL1A2]
# 3     [COL4A1, IGFBP7, COL4A2, IFITM3, DLC1, COL1A1, GPX3, COL1A2]
# 4           [COL4A1, IGFBP7, COL4A2, IFITM3, DLC1, COL1A1, COL1A2]
# 5             [IGFBP7, COL4A2, IFITM3, CSF1, COL1A1, GPX3, COL1A2]
# 6           [COL4A1, IGFBP7, COL4A2, IFITM3, COL1A1, GPX3, COL1A2]
# 7           [COL4A1, IGFBP7, COL4A2, IFITM3, COL1A1, GPX3, COL1A2]
# 8           [COL4A1, IGFBP7, COL4A2, IFITM3, COL1A1, GPX3, COL1A2]
# 9           [COL4A1, IGFBP7, COL4A2, IFITM3, COL1A1, GPX3, COL1A2]
# 10            [IGFBP7, COL4A2, IFITM3, CSF1, COL1A1, GPX3, COL1A2]
# 11          [COL4A1, IGFBP7, COL4A2, IFITM3, COL1A1, GPX3, COL1A2]
# 12          [COL4A1, IGFBP7, COL4A2, IFITM3, COL1A1, GPX3, COL1A2]
# 13            [IGFBP7, COL4A2, IFITM3, CSF1, COL1A1, GPX3, COL1A2]
# 14                   [IGFBP7, IFITM3, S100B, SORBS2, GPX3, COL1A2]
# 15                   [IGFBP7, IFITM3, S100B, SORBS2, GPX3, COL1A2]
# 16                   [IGFBP7, IFITM3, S100B, SORBS2, GPX3, COL1A2]
# 17                  [COL4A1, IGFBP7, COL4A2, DLC1, COL1A1, COL1A2]
# 18                 [COL4A1, IGFBP7, COL4A2, CSRP1, COL1A1, COL1A2]
# 19                 [COL4A1, IGFBP7, COL4A2, CSRP1, COL1A1, COL1A2]
#
#
# ================================================================================
# 29
#  (15/35)
# ================================================================================
#
#                                                                       Name  \
# Rank
# 0              SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 1                 SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 2     SmInt_Child04-06-Hematopoietic-Myeloid-MMP9+_Inflammatory_macrophage
# 3                                   SmInt_Child09-12-Hematopoietic-Myeloid
#
#      Marker Matches  \
# Rank
# 0           13 / 20
# 1           13 / 20
# 2           11 / 20
# 3           11 / 20
#
#                                                                                   Genes
# Rank
# 0     [CD14, DAB2, LYZ, AIF1, MRC1, FCGRT, MAFB, PLTP, CD163, CD4, CSF1R, APOE, FCER1G]
# 1     [CD14, DAB2, LYZ, AIF1, MRC1, FCGRT, MAFB, PLTP, CD163, CD4, CSF1R, APOE, FCER1G]
# 2                  [CD14, DAB2, LYZ, AIF1, MAFB, CD163, CD4, CSF1R, APOE, MMP9, FCER1G]
# 3                  [CD14, DAB2, LYZ, AIF1, MRC1, MAFB, CD163, CD4, CSF1R, MMP9, FCER1G]
#
#
# ================================================================================
# 13
#  (16/35)
# ================================================================================
#
#                                                                  Name  \
# Rank
# 0              SmInt_Child04-06-Hematopoietic-B_cells-FCRL4+_Memory_B
# 1                                   SmInt_Adult-Hematopoietic-B_cells
# 2                          SmInt_Adult-Hematopoietic-B_cells-Memory_B
# 3                                              SmInt_Child04-06|World
# 4                     SmInt_Child09-12-Hematopoietic-B_cells-Memory_B
# 5     SmInt_GW_trimst-1-Hematopoietic-B_cells-Pre-B|SmInt_GW_trimst-1
#
#      Marker Matches  \
# Rank
# 0           10 / 20
# 1           10 / 20
# 2           10 / 20
# 3           10 / 20
# 4           10 / 20
# 5            9 / 20
#
#                                                                         Genes
# Rank
# 0       [SP110, CTSH, PTPN1, CD79A, CD79B, BANK1, LTB, CD52, INPP5D, RNASET2]
# 1         [IRF8, SP110, LBH, ARHGDIB, CD79A, CD79B, BANK1, LTB, CD52, INPP5D]
# 2       [IRF8, SP110, ARHGDIB, CD79A, CD79B, BANK1, LTB, CD52, INPP5D, IKZF3]
# 3       [IRF8, BIRC3, ARHGDIB, CD79A, CD79B, BANK1, LTB, CD52, INPP5D, IKZF3]
# 4     [IRF8, SP110, ARHGDIB, CD79A, CD79B, BANK1, LTB, CD52, INPP5D, RNASET2]
# 5             [SP110, BIRC3, ARHGDIB, CD79A, CD79B, BANK1, LTB, CD52, INPP5D]
#
#
# ================================================================================
# 15
#  (17/35)
# ================================================================================
#
#                                                                                  Name  \
# Rank
# 0                           SmInt_GW_trimst-2-Hematopoietic-Myeloid|SmInt_GW_trimst-2
# 1                       SmInt_GW_trimst-1.5-Hematopoietic-Myeloid|SmInt_GW_trimst-1.5
# 2               SmInt_GW_trimst-2-Hematopoietic-Myeloid-Macrophages|SmInt_GW_trimst-2
# 3           SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-Macrophages|SmInt_GW_trimst-1.5
# 4                         SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 5                                 SmInt_Adult-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 6                                              SmInt_Adult-Hematopoietic-Myeloid-cDC2
# 7                      SmInt_GW_trimst-2-Hematopoietic-Myeloid-cDC2|SmInt_GW_trimst-2
# 8                               SmInt_Pediatric_IBD-Hematopoietic-Myeloid-Macrophages
# 9                                       SmInt_Adult-Hematopoietic-Myeloid-Macrophages
# 10                          SmInt_GW_trimst-1-Hematopoietic-Myeloid|SmInt_GW_trimst-1
# 11                                                  SmInt_Adult-Hematopoietic-Myeloid
# 12                                             SmInt_Child04-06-Hematopoietic-Myeloid
# 13                                        SmInt_Child09-12-Hematopoietic-Myeloid-cDC2
# 14                                 SmInt_Child09-12-Hematopoietic-Myeloid-Macrophages
# 15                                 SmInt_Child04-06-Hematopoietic-Myeloid-Macrophages
# 16                           SmInt_Child09-12-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 17                                        SmInt_Child04-06-Hematopoietic-Myeloid-cDC2
# 18                                     SmInt_Pediatric_IBD-Hematopoietic-Myeloid-cDC2
# 19                 SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-cDC2|SmInt_GW_trimst-1.5
# 20                                             SmInt_Child09-12-Hematopoietic-Myeloid
# 21                           SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 22    SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1.5
# 23              SmInt_GW_trimst-1-Hematopoietic-Myeloid-Macrophages|SmInt_GW_trimst-1
# 24        SmInt_GW_trimst-1-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1
#
#      Marker Matches  \
# Rank
# 0           15 / 20
# 1           14 / 20
# 2           14 / 20
# 3           13 / 20
# 4           13 / 20
# 5           13 / 20
# 6           13 / 20
# 7           13 / 20
# 8           13 / 20
# 9           13 / 20
# 10          13 / 20
# 11          13 / 20
# 12          13 / 20
# 13          12 / 20
# 14          12 / 20
# 15          12 / 20
# 16          12 / 20
# 17          12 / 20
# 18          12 / 20
# 19          12 / 20
# 20          12 / 20
# 21          12 / 20
# 22          12 / 20
# 23          12 / 20
# 24          12 / 20
#
#                                                                                                       Genes
# Rank
# 0     [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, ARHGDIB, HCK, MAFB, CD163, CD4, RNASET2, CSF1R, CSF2RA, FCER1G]
# 1             [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, ARHGDIB, HCK, MAFB, CD1C, CD163, CSF1R, CSF2RA, FCER1G]
# 2              [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, RNASET2, CSF1R, CSF2RA, FCER1G]
# 3               [SPI1, IL10RA, AIF1, MRC1, JAML, ARHGDIB, HCK, MAFB, CD163, RNASET2, CSF1R, CSF2RA, FCER1G]
# 4                       [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 5                   [SPI1, IL10RA, AIF1, MRC1, ARHGDIB, HCK, MAFB, CD1C, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 6                  [SPI1, AIF1, MRC1, JAML, ARHGDIB, HCK, CD1C, CD163, CD4, RNASET2, CSF1R, CSF2RA, FCER1G]
# 7                  [SPI1, IL10RA, LYZ, AIF1, JAML, ARHGDIB, HCK, CD1C, CD4, RNASET2, CSF1R, CSF2RA, FCER1G]
# 8                         [SPI1, LYZ, AIF1, MRC1, CTSH, JAML, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 9                   [SPI1, IL10RA, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, RNASET2, CSF1R, CSF2RA, FCER1G]
# 10                  [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, ARHGDIB, HCK, CD1C, CD163, CSF1R, CSF2RA, FCER1G]
# 11                  [SPI1, IL10RA, AIF1, MRC1, JAML, ARHGDIB, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 12                     [SPI1, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, RNASET2, CSF1R, CSF2RA, FCER1G]
# 13                               [SPI1, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD1C, CD4, CSF1R, CSF2RA, FCER1G]
# 14                              [SPI1, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 15                            [IL10RA, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 16                              [SPI1, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 17                               [SPI1, LYZ, AIF1, MRC1, CTSH, JAML, HCK, CD1C, CD4, CSF1R, CSF2RA, FCER1G]
# 18                               [SPI1, LYZ, AIF1, MRC1, CTSH, JAML, HCK, CD1C, CD4, CSF1R, CSF2RA, FCER1G]
# 19                      [SPI1, IL10RA, LYZ, AIF1, JAML, ARHGDIB, HCK, CD1C, RNASET2, CSF1R, CSF2RA, FCER1G]
# 20                              [SPI1, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 21                            [IL10RA, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 22                        [SPI1, IL10RA, AIF1, MRC1, ARHGDIB, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
# 23                       [SPI1, IL10RA, AIF1, MRC1, JAML, ARHGDIB, HCK, MAFB, CD163, CSF1R, CSF2RA, FCER1G]
# 24                        [SPI1, IL10RA, AIF1, MRC1, ARHGDIB, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, FCER1G]
#
#
# ================================================================================
# 23
#  (18/35)
# ================================================================================
#
#                                                                     Name  \
# Rank
# 0     SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-1.5
# 1         SmInt_GW_trimst-2-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-2
# 2                       SmInt_Child04-06-Hematopoietic-T_cells-TRGV4_gdT
#
#      Marker Matches    Genes
# Rank
# 0             1 / 1  [APOBR]
# 1             1 / 1  [APOBR]
# 2             1 / 1  [APOBR]
#
#
# ================================================================================
# 6
#  (19/35)
# ================================================================================
#
#                                                                        Name  \
# Rank
# 0                               SmInt_Adult-Hematopoietic-T_cells-TRGV2_gdT
# 1                 SmInt_GW_trimst-2-Hematopoietic-T_cells|SmInt_GW_trimst-2
# 2       SmInt_GW_trimst-2-Hematopoietic-T_cells-NK_T_cell|SmInt_GW_trimst-2
# 3         SmInt_GW_trimst-2-Hematopoietic-T_cells-NK_cell|SmInt_GW_trimst-2
# 4     SmInt_GW_trimst-1.5-Hematopoietic-T_cells-NK_cell|SmInt_GW_trimst-1.5
# 5         SmInt_GW_trimst-1-Hematopoietic-T_cells-NK_cell|SmInt_GW_trimst-1
#
#      Marker Matches  \
# Rank
# 0           16 / 20
# 1           16 / 20
# 2           15 / 20
# 3           15 / 20
# 4           14 / 20
# 5           14 / 20
#
#                                                                                                            Genes
# Rank
# 0     [ETS1, IL10RA, CD69, CXCR4, ARHGDIB, PTPN22, CCL5, GFI1, MATK, NKG7, CD3D, CD3E, IKZF3, STAT4, GZMB, GZMK]
# 1       [CD44, ETS1, CD69, CXCR4, ARHGDIB, PTPN22, CCL5, GFI1, MATK, NKG7, CD3D, CD3E, IKZF3, STAT4, GZMB, GZMK]
# 2            [ETS1, CD69, ARHGDIB, PTPN22, CCL5, GFI1, MATK, NKG7, CD3D, INPP5D, CD3E, IKZF3, STAT4, GZMB, GZMK]
# 3            [CD44, ETS1, IFITM1, CD69, ARHGDIB, PTPN22, CCL5, MATK, NKG7, CD3D, CD3E, IKZF3, STAT4, GZMB, GZMK]
# 4                 [CD69, CXCR4, ARHGDIB, PTPN22, CCL5, MATK, NKG7, CD3D, INPP5D, CD3E, IKZF3, STAT4, GZMB, GZMK]
# 5                 [CD69, CXCR4, ARHGDIB, PTPN22, CCL5, MATK, NKG7, CD3D, INPP5D, CD3E, IKZF3, STAT4, GZMB, GZMK]
#
#
# ================================================================================
# 11
#  (20/35)
# ================================================================================
#
#                                                                      Name  \
# Rank
# 0          SmInt_GW_trimst-1-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-1
# 1     SmInt_GW_trimst-1-Hematopoietic-Myeloid-Monocytes|SmInt_GW_trimst-1
# 2                   SmInt_GW_trimst-1.5-Hematopoietic|SmInt_GW_trimst-1.5
# 3                       SmInt_GW_trimst-2-Hematopoietic|SmInt_GW_trimst-2
# 4          SmInt_GW_trimst-2-Hematopoietic-Myeloid-cDC1|SmInt_GW_trimst-2
#
#      Marker Matches                                     Genes
# Rank
# 0            6 / 13  [LST1, APOBR, JAML, HCK, PTPN22, CSF2RA]
# 1            6 / 13  [LST1, JAML, HCK, PTPN22, PLAUR, CSF2RA]
# 2            6 / 13  [LST1, APOBR, JAML, HCK, PTPN22, CSF2RA]
# 3            6 / 13   [LST1, JAML, CD69, HCK, PTPN22, CSF2RA]
# 4            5 / 13          [LST1, APOBR, JAML, HCK, CSF2RA]
#
#
# ================================================================================
# 18
#  (21/35)
# ================================================================================
#
#                                                                              Name  \
# Rank
# 0                                           SmInt_Child09-12-Mesenchymal-myocytic
# 1                             SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
# 2                          SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
# 3                                           SmInt_Child04-06-Mesenchymal-myocytic
# 4                                        SmInt_Pediatric_IBD-Mesenchymal-myocytic
# 5                             SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
# 6                        SmInt_GW_trimst-2-Mesenchymal-myocytic|SmInt_GW_trimst-2
# 7                         SmInt_Adult-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 8                                                SmInt_Adult-Mesenchymal-myocytic
# 9           SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-2
# 10      SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1.5
# 11    SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-2
# 12          SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1
# 13                       SmInt_GW_trimst-1-Mesenchymal-myocytic|SmInt_GW_trimst-1
# 14                   SmInt_GW_trimst-1.5-Mesenchymal-myocytic|SmInt_GW_trimst-1.5
# 15                SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 16                   SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 17    SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-1
#
#      Marker Matches  \
# Rank
# 0           17 / 20
# 1           17 / 20
# 2           17 / 20
# 3           17 / 20
# 4           17 / 20
# 5           16 / 20
# 6           16 / 20
# 7           15 / 20
# 8           15 / 20
# 9           15 / 20
# 10          15 / 20
# 11          14 / 20
# 12          14 / 20
# 13          14 / 20
# 14          14 / 20
# 15          13 / 20
# 16          13 / 20
# 17          13 / 20
#
#                                                                                                                     Genes
# Rank
# 0     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 1     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 2     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 3     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 4     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 5            [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 6             [COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, ENAH, TAGLN, COL1A1, COL1A2, MYLK]
# 7                    [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, TAGLN, MYLK]
# 8                    [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, TAGLN, MYLK]
# 9                     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, ENAH, TAGLN, MYLK]
# 10                       [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, ENAH, NPNT, TAGLN, MYLK]
# 11                             [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, ENAH, TAGLN, MYLK]
# 12                          [COL4A1, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, ENAH, TAGLN, MYLK]
# 13                          [COL4A1, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, ENAH, TAGLN, MYLK]
# 14                             [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, ENAH, TAGLN, MYLK]
# 15                                   [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, TAGLN, MYLK]
# 16                                   [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, TAGLN, MYLK]
# 17                              [ACTG2, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, GREM1, ACTA2, TAGLN, COL1A1, COL1A2, MYLK]
#
#
# ================================================================================
# 4
#  (22/35)
# ================================================================================
#
#                                                                  Name  \
# Rank
# 0     SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
#
#      Marker Matches  \
# Rank
# 0           11 / 20
#
#                                                                                    Genes
# Rank
# 0     [PDGFRA, PDPN, PDGFRB, CCL11, IL6ST, SERPINF1, CSF1, CHI3L1, COL1A1, GPX3, COL1A2]
#
#
# ...
#
#      Marker Matches  \
# Rank
# 0           13 / 20
# 1           13 / 20
# 2           13 / 20
# 3           13 / 20
# 4           13 / 20
# 5           12 / 20
# 6           12 / 20
# 7           12 / 20
# 8           12 / 20
# 9           12 / 20
# 10          11 / 20
# 11          11 / 20
# 12           9 / 20
# 13           9 / 20
# 14           9 / 20
#
#                                                                                                    Genes
# Rank
# 0     [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, IFITM3, GJA4, CCDC3, ACTA2, DLC1, COL1A1, COL1A2, CCDC102B]
# 1     [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, IFITM3, GJA4, CCDC3, ACTA2, DLC1, COL1A1, COL1A2, CCDC102B]
# 2     [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, IFITM3, GJA4, CCDC3, ACTA2, DLC1, COL1A1, COL1A2, CCDC102B]
# 3     [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, IFITM3, GJA4, CCDC3, ACTA2, DLC1, COL1A1, COL1A2, CCDC102B]
# 4     [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, IFITM3, GJA4, CCDC3, ACTA2, DLC1, COL1A1, COL1A2, CCDC102B]
# 5                [COL4A1, IGFBP7, COL4A2, LBH, PDGFRB, IFITM1, RGS5, GJA4, CCDC3, ACTA2, DLC1, CCDC102B]
# 6                [COL4A1, IGFBP7, COL4A2, LBH, PDGFRB, IFITM1, RGS5, GJA4, CCDC3, ACTA2, DLC1, CCDC102B]
# 7                [COL4A1, IGFBP7, COL4A2, LBH, PDGFRB, RGS5, GJA4, MTHFD2, CCDC3, ACTA2, DLC1, CCDC102B]
# 8             [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, GJA4, CCDC3, ACTA2, DLC1, COL1A1, COL1A2, CCDC102B]
# 9                [COL4A1, IGFBP7, COL4A2, LBH, PDGFRB, RGS5, GJA4, MTHFD2, CCDC3, ACTA2, DLC1, CCDC102B]
# 10                      [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, GJA4, CCDC3, ACTA2, CSF1, DLC1, CCDC102B]
# 11                     [COL4A1, IGFBP7, COL4A2, LBH, PDGFRB, RGS5, MTHFD2, CCDC3, ACTA2, DLC1, CCDC102B]
# 12                                    [COL4A1, COL4A2, PDGFRB, RGS5, GJA4, CCL19, ACTA2, DLC1, CCDC102B]
# 13                                     [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, GJA4, CCDC3, CCL19, ACTA2]
# 14                                     [COL4A1, IGFBP7, COL4A2, PDGFRB, RGS5, GJA4, CCDC3, CCL19, ACTA2]
#
#
# ================================================================================
# 10
#  (30/35)
# ================================================================================
#
#                                                                                  Name  \
# Rank
# 0                         SmInt_Pediatric_IBD-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 1         SmInt_GW_trimst-2-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-2
# 2                            SmInt_Child04-06-Hematopoietic-Myeloid-LYVE1+_Macrophage
# 3     SmInt_GW_trimst-1.5-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1.5
# 4         SmInt_GW_trimst-1-Hematopoietic-Myeloid-LYVE1+_Macrophage|SmInt_GW_trimst-1
# 5                                       SmInt_Adult-Hematopoietic-Myeloid-Macrophages
#
#      Marker Matches  \
# Rank
# 0           16 / 20
# 1           16 / 20
# 2           15 / 20
# 3           14 / 20
# 4           13 / 20
# 5           13 / 20
#
#                                                                                                            Genes
# Rank
# 0           [CD14, DAB2, IL10RA, LYZ, AIF1, MRC1, FCGRT, MAFB, PLTP, CD163, CD4, CSF1R, APOE, MAF, NAIP, FCER1G]
# 1     [CD14, DAB2, IL10RA, AIF1, MRC1, LYVE1, MAFB, PLTP, RNASE1, CD163, CD4, RNASET2, CSF1R, MAF, NAIP, FCER1G]
# 2                [CD14, DAB2, IL10RA, LYZ, AIF1, MRC1, FCGRT, MAFB, PLTP, CD163, CD4, CSF1R, APOE, NAIP, FCER1G]
# 3                    [CD14, DAB2, IL10RA, AIF1, MRC1, LYVE1, MAFB, RNASE1, CD163, CD4, CSF1R, MAF, NAIP, FCER1G]
# 4                          [CD14, DAB2, IL10RA, AIF1, MRC1, LYVE1, MAFB, RNASE1, CD163, CD4, CSF1R, MAF, FCER1G]
# 5                         [CD14, DAB2, IL10RA, AIF1, MRC1, MAFB, PLTP, CD163, CD4, RNASET2, CSF1R, NAIP, FCER1G]
#
#
# ================================================================================
# 24
#  (31/35)
# ================================================================================
#
#                                                                  Name  \
# Rank
# 0     SmInt_Child04-06-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)
# 1                                SmInt_Adult-Mesenchymal-fibroblastic
#
#      Marker Matches  \
# Rank
# 0           11 / 20
# 1           11 / 20
#
#                                                                                     Genes
# Rank
# 0     [IGFBP6, PDGFRA, PDPN, PDGFRB, IFITM3, IL6ST, SERPINF1, CSF1, COL1A1, GPX3, COL1A2]
# 1      [IGFBP6, PDGFRA, PDPN, PDGFRB, MFAP5, SERPINF1, GREM1, APOD, COL1A1, GPX3, COL1A2]
#
#
# ================================================================================
# 33
#  (32/35)
# ================================================================================
#
#                                                                        Name  \
# Rank
# 0     SmInt_Pediatric_IBD-Mesenchymal-Pericytes-Contractile_pericyte_(PLN+)
# 1        SmInt_Child04-06-Mesenchymal-Pericytes-Contractile_pericyte_(PLN+)
# 2           SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 3                            SmInt_Adult-Mesenchymal-myocytic-myofibroblast
# 4                                     SmInt_Child09-12-Mesenchymal-myocytic
# 5              SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 6                       SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
#
#      Marker Matches                                  Genes
# Rank
# 0             6 / 6  [CNN1, NET1, MYH11, DES, TAGLN, MYLK]
# 1             5 / 6        [CNN1, MYH11, DES, TAGLN, MYLK]
# 2             5 / 6        [CNN1, MYH11, DES, TAGLN, MYLK]
# 3             5 / 6        [CNN1, MYH11, DES, TAGLN, MYLK]
# 4             5 / 6        [CNN1, MYH11, DES, TAGLN, MYLK]
# 5             5 / 6        [CNN1, MYH11, DES, TAGLN, MYLK]
# 6             5 / 6        [CNN1, MYH11, DES, TAGLN, MYLK]
#
#
# ================================================================================
# 7
#  (33/35)
# ================================================================================
#
#                                                                              Name  \
# Rank
# 0           SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-2
# 1                          SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
# 2                                        SmInt_Pediatric_IBD-Mesenchymal-myocytic
# 3                        SmInt_GW_trimst-2-Mesenchymal-myocytic|SmInt_GW_trimst-2
# 4                                           SmInt_Child09-12-Mesenchymal-myocytic
# 5                         SmInt_Adult-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 6                                                SmInt_Adult-Mesenchymal-myocytic
# 7     SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-2
# 8                             SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
# 9                                           SmInt_Child04-06-Mesenchymal-myocytic
# 10                       SmInt_GW_trimst-1-Mesenchymal-myocytic|SmInt_GW_trimst-1
# 11          SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1
# 12                   SmInt_GW_trimst-1.5-Mesenchymal-myocytic|SmInt_GW_trimst-1.5
# 13      SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1.5
# 14                            SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
# 15                SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 16                   SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
#
#      Marker Matches  \
# Rank
# 0           16 / 16
# 1           15 / 16
# 2           15 / 16
# 3           15 / 16
# 4           14 / 16
# 5           14 / 16
# 6           14 / 16
# 7           14 / 16
# 8           14 / 16
# 9           14 / 16
# 10          14 / 16
# 11          14 / 16
# 12          14 / 16
# 13          14 / 16
# 14          13 / 16
# 15          12 / 16
# 16          12 / 16
#
#                                                                                                          Genes
# Rank
# 0     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 1           [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, TAGLN, MYLK]
# 2           [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, TAGLN, MYLK]
# 3             [COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 4                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 5                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 6                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 7                     [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 8                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 9                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 10                 [COL4A1, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 11                 [COL4A1, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 12                    [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 13                    [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 14                      [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, ACTA2, TAGLN, MYLK]
# 15                               [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 16                               [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
#
#
# ================================================================================
# 1
#  (34/35)
# ================================================================================
#
#                                                                                  Name  \
# Rank
# 0               SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-2
# 1         SmInt_GW_trimst-2-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-2
# 2                              SmInt_Pediatric_IBD-Mesenchymal-myocytic-myofibroblast
# 3                            SmInt_GW_trimst-2-Mesenchymal-myocytic|SmInt_GW_trimst-2
# 4                                            SmInt_Pediatric_IBD-Mesenchymal-myocytic
# 5                        SmInt_GW_trimst-1.5-Mesenchymal-myocytic|SmInt_GW_trimst-1.5
# 6                                               SmInt_Child09-12-Mesenchymal-myocytic
# 7                             SmInt_Adult-Mesenchymal-myocytic-myofibroblast_(RSPO2+)
# 8                                                    SmInt_Adult-Mesenchymal-myocytic
# 9                                 SmInt_Child04-06-Mesenchymal-myocytic-myofibroblast
# 10                                              SmInt_Child04-06-Mesenchymal-myocytic
# 11              SmInt_GW_trimst-1-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1
# 12                           SmInt_GW_trimst-1-Mesenchymal-myocytic|SmInt_GW_trimst-1
# 13          SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PLPP2+)|SmInt_GW_trimst-1.5
# 14                                SmInt_Child09-12-Mesenchymal-myocytic-myofibroblast
# 15    SmInt_GW_trimst-1.5-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|SmInt_GW_trimst-1.5
#
#      Marker Matches  \
# Rank
# 0           16 / 20
# 1           15 / 20
# 2           15 / 20
# 3           15 / 20
# 4           15 / 20
# 5           15 / 20
# 6           14 / 20
# 7           14 / 20
# 8           14 / 20
# 9           14 / 20
# 10          14 / 20
# 11          14 / 20
# 12          14 / 20
# 13          14 / 20
# 14          13 / 20
# 15          13 / 20
#
#                                                                                                          Genes
# Rank
# 0     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 1              [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, RAMP1, ENAH, TAGLN, MYLK]
# 2           [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, TAGLN, MYLK]
# 3             [COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 4           [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, TAGLN, MYLK]
# 5              [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, RAMP1, ENAH, TAGLN, MYLK]
# 6                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 7                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 8                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 9                [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 10               [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, MYLK]
# 11                 [COL4A1, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 12                 [COL4A1, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 13                    [PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 14                      [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, ACTA2, TAGLN, MYLK]
# 15                        [ACTG2, RGS5, DES, PDLIM7, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, RAMP1, TAGLN, MYLK]
#
#
# ================================================================================
# 34
#  (35/35)
# ================================================================================
#
#                                                              Name  \
# Rank
# 0     Enterocyte-C_02|Enterocyte / shred on cell type and cluster
# 1           SmInt_Child09-12-Epithelial-mature_enterocytic-Paneth
#
#      Marker Matches    Genes
# Rank
# 0             1 / 1  [CDCA7]
# 1             1 / 1  [CDCA7]
#
#
# Failed: 23    sequence item 1: expected str instance, int found
# dtype: object
# CPU times: user 15min 48s, sys: 1min 36s, total: 17min 25s
# Wall time: 17min 34s

# %% [markdown]
# ## By Specific Genes

# %%
# %%time

ggg = pd.DataFrame(["CDKN1A", "CDKN2A", "TP53", "PLAUR", "IL6ST"])[
    0].to_frame("Gene").assign(Annotation="Senescence").set_index("Gene")
outs_bg, failed = {}, []  # hold results
for i, k in enumerate(self.rna.obs[c_t].unique()):
    outs_bg[k] = self.print_markers(
        k, ggg, col_cell_type=c_t, lfc_threshold=None, print_threshold=0,
        count_threshold=count_threshold, p_threshold=None, n_top_genes=None)
if len(failed) > 0:
    print(f"Failed: {pd.Series(dict(failed))}")

# %% [markdown]
# ## Write

# %%
for i, x in enumerate([outs, outs_bg]):
    quant = {}
    for k in outs:
        percs_exp, n_exp = x[k][1].copy(), x[k][2].copy()
        quant[k] = pd.concat([
            x.rename_axis("Measure", axis=1).stack() for x in [
                percs_exp.rename_axis("Cell Types", axis=1).stack().replace(
                    "", np.nan).dropna().to_frame("n_exp"), n_exp.set_index(
                        "Cell Types", append=True).rename({
                            k: "Cluster"}, axis=1)]], keys=[
                                "quantification", "representation"]).unstack(
                                    0).unstack(-1).dropna(how="all", axis=1)
    quant = pd.concat(quant, names=["Cluster"])
    if out_dir:
        suf = "" if i == 0 else "_" + "_".join(ggg.reset_index(
            ).Gene.unique().to_list())  # file suffix if by gene
        q_file = os.path.join(
            out_dir, "quantification",
            f"{self._library_id}__{c_t}_quantification_annotation{suf}.xlsx")
        print(f"Writing to {q_file}")
        quant.to_excel(q_file)

# %% [markdown]
# # View

# %% [markdown]
# ## ToppGene/Quantifications

# %%
key_cluster = "34"
output = outs  # see "by markers" version
# output = outs_bg  # see "by specific genes" version

if tgdf is not None and key_cluster in tgdf.reset_index(1).index.values:
    print(f"{'=' * 80}\n\n{key_cluster}\n\n"
          f"{tgdf.loc[key_cluster].iloc[:, :-3]}")
_, percs_exp, n_exp, genes, msg = outs[key_cluster]
n_exp = n_exp.copy().set_index("Cell Types", append=True)
print(percs_exp.applymap(lambda x: x if x == "" else str(
    int(x)) + "%").stack().replace("", np.nan).dropna().sort_values(
            ascending=False).head(20))
print(f"{genes}\n\n{n_exp.applymap(int)}\n\n{msg}")
print(f"\n\nN = {sum(self.rna.obs[c_t] == k)}\n\n")
percs_exp.applymap(lambda x: x if x == "" else str(int(x)) + "%")
# Out:
# Gene
# NACA      CLP                            99%
# CFB       Mesothelium (PRG4+)            95%
# SLC39A8   Mesothelium (PRG4+)            94%
#           BEST2+ Goblet cell             94%
# COL1A1    Glia 1 (DHH+)                  92%
#           Neural                         92%
#           Stromal 3 (C7+)                92%
# AQP1      Glia 2 (ELN+)                  89%
#           Endothelial                    89%
# HSP90AA1  ILC1                           88%
# SNX3      cDC1                           85%
# SORBS2    Adult Glia                     79%
#           Contractile pericyte (PLN+)    79%
#           Mesenchymal                    79%
#           arterial capillary             79%
# FOSL2     TRGV4 gdT                      72%
#           Monocytes                      72%
# DAB2      Myeloid                        71%
#           LYVE1+ Macrophage              71%
# HSPA1B    myofibroblast (RSPO2+)         64%
# dtype: object
# group
# Adult Glia                              SORBS2
# BEST2+ Goblet cell                     SLC39A8
# CLP                                       NACA
# Contractile pericyte (PLN+)             SORBS2
# Endothelial                               AQP1
# Glia 1 (DHH+)                           COL1A1
# Glia 2 (ELN+)                             AQP1
# Glia 3 (BCAN+)                         TPD52L1
# ILC1                                  HSP90AA1
# LYVE1+ Macrophage                         DAB2
# Mature venous EC                       TPD52L1
# Mesenchymal                             SORBS2
# Mesothelium (PRG4+)               SLC39A8, CFB
# Mesothelium (RGS5+)                      PODXL
# Monocytes                                FOSL2
# Myeloid                                   DAB2
# Neural                         COL1A1, TPD52L1
# Stromal 3 (C7+)                         COL1A1
# TRGV4 gdT                                FOSL2
# arterial capillary                      SORBS2
# cDC1                                      SNX3
# myofibroblast (RSPO2+)                  HSPA1B
# dtype: object
#
#                                                                                     34  \
# Gene     Cell Types
# SLC39A8  BEST2+ Goblet cell, Mesothelium (PRG4+)                                   105
# PODXL    Mesothelium (RGS5+)                                                        64
# TPD52L1  Mature venous EC, Glia 3 (BCAN+), Neural                                   56
# SORBS2   Contractile pericyte (PLN+), arterial capillary, Adult Glia, Mesenchymal   88
# CFB      Mesothelium (PRG4+)                                                       106
# DAB2     LYVE1+ Macrophage, Myeloid                                                 79
# FOSL2    TRGV4 gdT, Monocytes                                                       80
# HSPA1B   myofibroblast (RSPO2+)                                                     72
# AQP1     Glia 2 (ELN+), Endothelial                                                 99
# COL1A1   Stromal 3 (C7+), Glia 1 (DHH+), Neural                                    103
# HSP90AA1 ILC1                                                                       98
# SNX3     cDC1                                                                       95
# NACA     CLP                                                                       110
#
#                                                                                     Other  \
# Gene     Cell Types
# SLC39A8  BEST2+ Goblet cell, Mesothelium (PRG4+)                                    14387
# PODXL    Mesothelium (RGS5+)                                                         9371
# TPD52L1  Mature venous EC, Glia 3 (BCAN+), Neural                                    8480
# SORBS2   Contractile pericyte (PLN+), arterial capillary, Adult Glia, Mesenchymal   22656
# CFB      Mesothelium (PRG4+)                                                        36757
# DAB2     LYVE1+ Macrophage, Myeloid                                                 28151
# FOSL2    TRGV4 gdT, Monocytes                                                       45447
# HSPA1B   myofibroblast (RSPO2+)                                                     42012
# AQP1     Glia 2 (ELN+), Endothelial                                                 66068
# COL1A1   Stromal 3 (C7+), Glia 1 (DHH+), Neural                                     83499
# HSP90AA1 ILC1                                                                       93598
# SNX3     cDC1                                                                       94779
# NACA     CLP                                                                       170907
#
#                                                                                     Total  \
# Gene     Cell Types
# SLC39A8  BEST2+ Goblet cell, Mesothelium (PRG4+)                                    14492
# PODXL    Mesothelium (RGS5+)                                                         9435
# TPD52L1  Mature venous EC, Glia 3 (BCAN+), Neural                                    8536
# SORBS2   Contractile pericyte (PLN+), arterial capillary, Adult Glia, Mesenchymal   22744
# CFB      Mesothelium (PRG4+)                                                        36863
# DAB2     LYVE1+ Macrophage, Myeloid                                                 28230
# FOSL2    TRGV4 gdT, Monocytes                                                       45527
# HSPA1B   myofibroblast (RSPO2+)                                                     42084
# AQP1     Glia 2 (ELN+), Endothelial                                                 66167
# COL1A1   Stromal 3 (C7+), Glia 1 (DHH+), Neural                                     83602
# HSP90AA1 ILC1                                                                       93696
# SNX3     cDC1                                                                       94874
# NACA     CLP                                                                       171017
#
#                                                                                    Percent_Total
# Gene     Cell Types
# SLC39A8  BEST2+ Goblet cell, Mesothelium (PRG4+)                                               0
# PODXL    Mesothelium (RGS5+)                                                                   0
# TPD52L1  Mature venous EC, Glia 3 (BCAN+), Neural                                              0
# SORBS2   Contractile pericyte (PLN+), arterial capillary, Adult Glia, Mesenchymal              0
# CFB      Mesothelium (PRG4+)                                                                   0
# DAB2     LYVE1+ Macrophage, Myeloid                                                            0
# FOSL2    TRGV4 gdT, Monocytes                                                                  0
# HSPA1B   myofibroblast (RSPO2+)                                                                0
# AQP1     Glia 2 (ELN+), Endothelial                                                            0
# COL1A1   Stromal 3 (C7+), Glia 1 (DHH+), Neural                                                0
# HSP90AA1 ILC1                                                                                  0
# SNX3     cDC1                                                                                  0
# NACA     CLP                                                                                   0
#
# 99% NACA+; 95% CFB+; 94% SLC39A8+; 92% COL1A1+; 89% AQP1+; 88% HSP90AA1+; 85% SNX3+; 79% SORBS2+; 72% FOSL2+; 71% DAB2+; 64% HSPA1B+; 57% PODXL+; 50% TPD52L1+ (>=1 counts)
#
#
# N = 1899
#          Adult Glia BEST2+ Goblet cell  CLP Contractile pericyte (PLN+)  \
# Gene
# AQP1
# CFB
# COL1A1
# DAB2
# FOSL2
# HSP90AA1
# HSPA1B
# NACA                                    99%
# PODXL
# SLC39A8                            94%
# SNX3
# SORBS2          79%                                                 79%
# TPD52L1
#
#          Endothelial Glia 1 (DHH+) Glia 2 (ELN+) Glia 3 (BCAN+) ILC1  \
# Gene
# AQP1             89%                         89%
# CFB
# COL1A1                         92%
# DAB2
# FOSL2
# HSP90AA1                                                         88%
# HSPA1B
# NACA
# PODXL
# SLC39A8
# SNX3
# SORBS2
# TPD52L1                                                     50%
#
#          LYVE1+ Macrophage Mature venous EC Mesenchymal Mesothelium (PRG4+)  \
# Gene
# AQP1
# CFB                                                                     95%
# COL1A1
# DAB2                   71%
# FOSL2
# HSP90AA1
# HSPA1B
# NACA
# PODXL
# SLC39A8                                                                 94%
# SNX3
# SORBS2                                              79%
# TPD52L1                                 50%
#
#          Mesothelium (RGS5+) Monocytes Myeloid Neural Stromal 3 (C7+)  \
# Gene
# AQP1
# CFB
# COL1A1                                            92%             92%
# DAB2                                       71%
# FOSL2                              72%
# HSP90AA1
# HSPA1B
# NACA
# PODXL                    57%
# SLC39A8
# SNX3
# SORBS2
# TPD52L1                                           50%
#
#          TRGV4 gdT arterial capillary cDC1 myofibroblast (RSPO2+)
# Gene
# AQP1
# CFB
# COL1A1
# DAB2
# FOSL2          72%
# HSP90AA1
# HSPA1B                                                        64%
# NACA
# PODXL
# SLC39A8
# SNX3                                   85%
# SORBS2                            79%
# TPD52L1

# %% [markdown]
# ## Plotting

# %%
fig, axis = plt.subplots(1, 2)
self.plot_spatial(color=c_t, groups=["32"], ax=axis[0])
self.plot_spatial("Stricture-50336A___morphology_focus_scale4", ax=axis[1])

# %% [markdown]
# ## Specific to Subsets of Cell Types

# %%
# comp = ["0", "5", "8", "10", "18", "20", "34"]
comp = ["2", "7", "11", "21", "28"]
count_threshold = 1
key_cluster = "2"
_, percs_exp, n_exp, genes, msg = self.print_markers(
    key_cluster, assign, col_cell_type=c_t, lfc_threshold=None,
    key_compare=comp, count_threshold=count_threshold, p_threshold=1,
    n_top_genes=list(assign[assign.Lump == "Epithelial"].index.intersection(
        self.rna.var_names)) + ["TP53", "PLAUR"])
n_exp = n_exp.copy().set_index("Cell Types", append=True)
print(f"{genes}\n\n{n_exp.applymap(int)}\n\n{msg}")
percs_exp.applymap(lambda x: x if x == "" else str(int(x)) + "%")

# %% [markdown]
# # Write All Clusters

# %%
col_fff = "out_file"
fff = np.array(cr.pp.construct_file(directory=direc, panel_id=panel))
bff = np.array([os.path.basename(i) for i in fff])  # base path names
samps = np.array([i.split("__")[2].split("-")[0] for i in fff])
for x in metadata[cso]:
    m_f = metadata[metadata[cso] == x][
        "out_file"].iloc[0]  # ...use to find unconventionally-named files
    locx = np.where(samps == x)[0] if pd.isnull(
        m_f) else np.where(bff == m_f)[0]
    metadata.loc[metadata[cso] == x, col_fff] = fff[locx[0]] if (
        len(locx) > 0) else np.nan  # assign output file to metadata row
metadata = metadata.dropna(subset=[col_fff]).drop_duplicates().set_index(cso)

# %%
# Load Spatial Data
for libid in samp_ids:
    if not os.path.exists(os.path.join(out_dir, samp_ids[libid] + ".h5ad")):
        print(f"\n\nWarning: Critical file(s) for {libid} not found.\n\n")
        continue
    self = cr.Spatial(metadata.loc[libid]["out_file"],
                      library_id=samp_ids[libid])
    self.update_from_h5ad(os.path.join(out_dir, samp_ids[libid] + ".h5ad"))
    if c_t not in self.rna.obs.columns:
        print(f"\n\nWarning: {c_t} column for {libid} not found.\n\n")
        continue
    self.write_clusters(out_dir, col_cell_type=c_t, overwrite=True,
                        file_prefix=f"{self._library_id}__",
                        n_top="find_markers")

# %%
c_t = "leiden_res1pt5_dist0_npc30"
# Faster way for spatial data

# import scanpy as sc

# c_t = "leiden_res1pt5_dist0_npc30"
clusterings = ["res1pt5_dist0_npc30"]

for libid in samp_ids:
    if not os.path.exists(os.path.join(out_dir, samp_ids[libid] + ".h5ad")):
        print(f"\n\nWarning: Critical file(s) for {libid} not found.\n\n")
        continue
    adata = sc.read(os.path.join(out_dir, samp_ids[libid] + ".h5ad"))
    for r in clusterings:
        c_t = f"leiden_{r}"
        if c_t not in adata.obs.columns:
            print(f"\n\nWarning: {c_t} column for {libid} not found.\n\n")
            continue
        fff = os.path.join(out_dir, f"{samp_ids[libid]}__{c_t}.csv")
        adata.obs.set_index("cell_id")[c_t].to_frame("group").to_csv(fff)
        fmr = pd.read_excel(os.path.join(
            out_dir, "annotation_dictionaries/annotations_all.xlsx"),
                            index_col=[0, 1]).iloc[:, :3].astype(str).dropna()
        if f"{samp_ids[libid]}___leiden_{r}_dictionary.xlsx" not in [
                v[0] for v in fmr.index]:
            print(f"{libid} not in annotation dictionary.")
            continue
        else:
            print(f"{libid} annotated.")
        fmr = fmr.loc[f"{samp_ids[libid]}___leiden_{r}_dictionary.xlsx"]
        mans = dict(fmr["annotation"])
        adata.obs.loc[:, f"manual_{r}"] = adata.obs[f"leiden_{r}"].astype(
            int).astype(str).replace(mans)  # Leiden -> manual annotation
        adata.obs.loc[adata.obs[f"manual_{r}"].isnull(
            ), f"manual_{r}"] = adata.obs.loc[adata.obs[
                f"manual_{r}"].isnull(), f"leiden_{r}"].astype(str)
        adata.obs.loc[:, f"manual_{r}"] = adata.obs[
            f"manual_{r}"].astype("category")  # as categorical
        fff = os.path.join(out_dir, f"{samp_ids[libid]}__manual_{r}.csv")
        adata.obs.set_index("cell_id")[f"manual_{r}"].to_frame(
            "group").to_csv(fff)
