# %% [markdown]
# # Annotation

# %% [markdown]
# # Options & Data

# %%
# %load_ext autoreload
# %autoreload 2

import os
import re
import functools
import numpy as np
import pandas as pd
import corescpy as cr

# Display
pd.options.display.max_colwidth = 1000
pd.options.display.max_columns = 100
pd.options.display.max_rows = 500

# Count Threshold for Cell Quantification
count_threshold = 1

# File Paths
panel = "TUQ97N"
libid = "Stricture-50403C2"
direc = "/mnt/cho_lab/bb-xenium-registry/"
dir_data = os.path.join(direc, f"outputs/{panel}")
dir_writeable = "/mnt/cho_lab/disk2/elizabeth/data/shared-xenium-library"
out_dir = os.path.join(dir_writeable, f"outputs/{panel}/nebraska")
mdf = os.path.join(dir_writeable, f"samples_{panel}.csv")  # metadata
path_ann = "~/corescpy/examples/markers_lineages.csv"

# Constants
constants_dict = cr.get_panel_constants(panel_id=panel)
cso, csid, col_condition, col_inflamed, col_stricture, key_stricture = [
    constants_dict[x] if x in constants_dict else None for x in [
        "col_sample_id_o", "col_sample_id", "col_condition", "col_inflamed",
        "col_stricture", "key_stricture"]]  # column & keys in columns

# Clustering Version
c_t = "leiden_res1pt5_dist0_npc30"  # high resolution
# c_t = "leiden_res0pt75_dist0pt3_npc30"  # medium resolution
# c_t = "leiden_res0pt5_dist0pt5_npc30"  # low resolution

# ToppGene Sources & Quantification Count Threshold
srcs = ["Cells of the human intestinal tract mapped across space and time",
        "Human Ileal Epithelial cells from Crohn’s Disease",
        "Human Ileal Immune cells from Crohn’s Disease"]
count_threshold = 1

# Annotation Guide File
anf = pd.read_csv(path_ann)
col_assignment = "group"
assign = anf.dropna(subset=col_assignment).set_index(
    "gene").rename_axis("Gene")  # markers

# Metadata & List of Existing Xenium Data Directories
metadata = (pd.read_excel if mdf[-4:] == "xlsx" else pd.read_csv)(mdf)
if col_stricture is not None and col_condition not in metadata.columns:
    metadata.loc[:, col_condition] = metadata.apply(
        lambda x: key_stricture.capitalize() if x[
            col_stricture].lower() in ["yes", key_stricture.lower()] else x[
                col_inflamed].capitalize(), axis=1)
metadata.loc[:, csid] = metadata[col_condition] + "-" + metadata[cso]
samp_ids = dict(metadata.set_index(cso)[csid])  # map libid to condition-ID
files = functools.reduce(lambda i, j: i + j, [[os.path.join(
    run, i) for i in os.listdir(os.path.join(
        dir_data, run))] for run in os.listdir(dir_data)])
# Out:
# Downloading data from `https://omnipathdb.org/queries/enzsub?format=json`
# Downloading data from `https://omnipathdb.org/queries/interactions?format=json`
# Downloading data from `https://omnipathdb.org/queries/complexes?format=json`
# Downloading data from `https://omnipathdb.org/queries/annotations?format=json`
# Downloading data from `https://omnipathdb.org/queries/intercell?format=json`
# Downloading data from `https://omnipathdb.org/about?format=text`

# %% [markdown]
# # Data

# %%
# Load Spatial Data
file_path = np.array(files)[np.where(["-".join(libid.split(
    "-")[1:]) == os.path.basename(x).split("__")[2].split(
        "-")[0] for x in files])[0][0]]  # find file for sample
self = cr.Spatial(os.path.join(dir_data, file_path), library_id=libid)
self.update_from_h5ad(os.path.join(out_dir, libid + ".h5ad"))
self.get_layer("counts", inplace=True)

# Write Cluster Files
# self.write_clusters(out_dir, col_cell_type=c, overwrite=True,
#                     file_prefix=f"{self._library_id}__", n_top=True)

# Auto-Annotation Results (If Available)
if f"label_{c_t.split('leiden_')[1]}" in self.rna.obs:
    print(f"\n\n{'=' * 80}\n\nAutomatic Annotation Results\n\n{'=' * 80}\n\n")
    self.rna.obs.groupby(c_t).apply(
        lambda x: x[f"label_{c_t.split('leiden_')[1]}"].unique()).apply(
            lambda x: x[0] if len(x) == 1 else x)
# Out:
# <<< INITIALIZING SPATIAL CLASS OBJECT >>>
#
# INFO     reading
#          /mnt/cho_lab/bb-xenium-registry/outputs/TUQ97N/CHO-012/output-XETG00189__0021979__50403C2-TUQ97N-EA__20240
#          516__190239/cell_feature_matrix.h5
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
#
#
# ================================================================================
# Counts: Initial: table
# ================================================================================
#
#
# 	Observations: 844288
#
# 	Genes: 469
#
#
#
# ================================================================================
#
#
#
#
#  AnnData object with n_obs × n_vars = 844288 × 469
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'region', 'z_level', 'nucleus_count', 'cell_labels', 'Sample'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatialdata_attrs', 'spatial'
#     obsm: 'spatial'
#     layers: 'counts'
#
#                 gene_ids    feature_types   genome
# ABCA7   ENSG00000064687  Gene Expression  Unknown
# ACTA2   ENSG00000107796  Gene Expression  Unknown
# ACTG2   ENSG00000163017  Gene Expression  Unknown
# ADAM15  ENSG00000143537  Gene Expression  Unknown
# ADAM28  ENSG00000042980  Gene Expression  Unknown
#
#
#
#
#
#
# SpatialData object
# ├── Images
# │     └── 'morphology_focus': DataTree[cyx] (5, 81651, 54057), (5, 40825, 27028), (5, 20412, 13514), (5, 10206, 6757), (5, 5103, 3378)
# ├── Labels
# │     ├── 'cell_labels': DataTree[yx] (81651, 54057), (40825, 27028), (20412, 13514), (10206, 6757), (5103, 3378)
# │     └── 'nucleus_labels': DataTree[yx] (81651, 54057), (40825, 27028), (20412, 13514), (10206, 6757), (5103, 3378)
# ├── Points
# │     └── 'transcripts': DataFrame with shape: (<Delayed>, 11) (3D points)
# ├── Shapes
# │     ├── 'cell_boundaries': GeoDataFrame shape: (844288, 1) (2D shapes)
# │     ├── 'cell_circles': GeoDataFrame shape: (844288, 2) (2D shapes)
# │     └── 'nucleus_boundaries': GeoDataFrame shape: (838461, 1) (2D shapes)
# └── Tables
#       └── 'table': AnnData (844288, 469)
# with coordinate systems:
#     ▸ 'global', with elements:
#         morphology_focus (Images), cell_labels (Labels), nucleus_labels (Labels), transcripts (Points), cell_boundaries (Shapes), cell_circles (Shapes), nucleus_boundaries (Shapes)
#
#
#
#
# col_gene_symbols=None
# col_cell_type="leiden"
# col_sample_id="Sample"
# col_batch="Sample"
# col_subject=None
# col_condition=None
# col_num_umis=None
# col_segment="region"
#
#
#
#
#
#
#
#
# key_control=None
# key_treatment=None
# key_table="table"
#
#
#
#
#
#
# <<< RESTORING SINGLE-SAMPLE FROM h5ad >>>
#
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
# WARNING: Unable to find `y`, `x` or `z` dimension in `('c', 'y', 'x')`. Renaming to `('channels', 'y', 'x', 'z')`
#
#
# ================================================================================
#
# Automatic Annotation Results
#
# ================================================================================

# %% [markdown]
# # ToppGene

# %%
if f"label_{c_t.split('leiden_')[1]}" in self.rna.obs:
    print(f"\n\n{'=' * 80}\n\nAutomatic Annotation Results\n\n{'=' * 80}\n\n")
    self.rna.obs.groupby(c_t).apply(
        lambda x: x[f"label_{c_t.split('leiden_')[1]}"].unique()).apply(
            lambda x: x[0] if len(x) == 1 else x)
# Out:
# ================================================================================
#
# Automatic Annotation Results
#
# ================================================================================

# %%
self.get_layer("counts", inplace=True)
tgdf, mks = self.annotate_clusters(
        None, sources=srcs, col_cell_type=c_t, max_results=10000,
        name_pattern={srcs[0]: "SmallIntestine"},
        # p_threshold=1e-15,
        p_threshold=1e-2,
        lfc_threshold=1, n_top_genes=20, n_top_annotations=40)
longs = [(" / Per Region, Age_group, Lineage, cell class, cell type", ""),
         ("SmallIntestine", "SmInt")]
for x in longs:
    tgdf.loc[:, "Name"] = tgdf.Name.apply(lambda y: re.sub(x[0], x[1], y))
tgdf.loc[:, "Name"] = tgdf.Name.apply(lambda y: "|".join(y.split("|")[
        :-1]) if y.split("|")[-1].split("-")[0] in y.split("-")[0] and (any(
            i in y for i in ["Child", "Adult", "Pediatric", "Trim"])) else y)
tgdf = tgdf.rename_axis([c_t, "Rank"])
tgdf = tgdf.join(tgdf.apply(
    lambda x: f"{x['GenesInTermInQuery']} / {x['GenesInQuery']}",
    axis=1).to_frame("Marker Matches"))
tgdf = tgdf[list(tgdf.columns[:1]) + ["Marker Matches"] + list(
        tgdf.columns[1:-1])]
tgdf = tgdf.rename_axis([c_t, "Rank"])
tgdf.sort_index()
# Out:
#                                                                                                                                                                                          Name  \
# leiden_res1pt5_dist0_npc30 Rank
# 0                          0                                3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            1                3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            2                      3'-Child09-12-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            3                3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells-IgG_plasma_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            4                      3'-Child04-06-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            5                                      3'-Child09-12-SmInt-Hematopoietic-Plasma_cells|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1                          0                                      3'-Child09-12-SmInt-Hematopoietic-T_cells-Th17|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            1                                 3'-Pediatric_IBD-SmInt-Hematopoietic-T_cells-Tfh|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            2                                       3'-Child04-06-SmInt-Hematopoietic-T_cells-Tfh|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2                          0                   3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            1                       3'-GW_trimst-1-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            2                       5'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            3                         3'-Child04-06-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            4                       3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            5                   5'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            6                         3'-Child09-12-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            7                                         3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3                          0                              3'-Child09-12-SmInt-Mesenchymal-myocytic-myofibroblast|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            1                                            3'-Child09-12-SmInt-Mesenchymal-myocytic|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            2                             5'-GW_trimst-2-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            3                                      3'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            4                                          3'-GW_trimst-2-SmInt-Mesenchymal-myocytic|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            5                             3'-GW_trimst-2-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            6                         3'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            7                        3'-Pediatric_IBD-SmInt-Mesenchymal-myocytic-myofibroblast|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            8                                      3'-Pediatric_IBD-SmInt-Mesenchymal-myocytic|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            9                              3'-Child04-06-SmInt-Mesenchymal-myocytic-myofibroblast|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            10                                           3'-Child04-06-SmInt-Mesenchymal-myocytic|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            11                        5'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            12                              5'-Adult-SmInt-Mesenchymal-myocytic-myofibroblast_(RSPO2+)|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            13                                                     5'-Adult-SmInt-Mesenchymal-myocytic|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            14                      5'-GW_trimst-2-SmInt-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            15                                         5'-GW_trimst-2-SmInt-Mesenchymal-myocytic|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            16              3'-Pediatric_IBD-SmInt-Mesenchymal-myocytic-myofibroblast_(RSPO2+)|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            17                                         3'-GW_trimst-1-SmInt-Mesenchymal-myocytic|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            18                            3'-GW_trimst-1-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            19                                     5'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            20                                                  3'-GW_trimst-1-SmInt-Mesenchymal|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            21                  3'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            22                    3'-Child09-12-SmInt-Mesenchymal-myocytic-myofibroblast_(RSPO2+)|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            23                                       5'-Adult-SmInt-Mesenchymal-myocytic-myofibroblast|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            24                      3'-GW_trimst-2-SmInt-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5                          0                               3'-Pediatric_IBD-SmInt-Endothelial-blood_vessel_EC|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            1                                               3'-Pediatric_IBD-SmInt-Endothelial|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            2            3'-Pediatric_IBD-SmInt-Endothelial-blood_vessel_EC-arterial_capillary|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            3                                   3'-GW_trimst-2-SmInt-Endothelial-blood_vessel_EC|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            4                                     3'-Child04-06-SmInt-Endothelial-blood_vessel_EC|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#                            5                
#                            15    1.971295e-29  1.841517e-28      4.211943e-28
#                            16    1.971295e-29  1.841517e-28      4.533979e-28
#                            17    6.122608e-27  5.719531e-26      1.653104e-25
#                            18    8.549588e-27  7.986734e-26      4.493816e-25
#                            19    8.549588e-27  7.986734e-26      4.812750e-25
#                            20    8.549588e-27  7.986734e-26      4.812750e-25
#                            21    8.549588e-27  7.986734e-26      5.152461e-25
#                            22    8.549588e-27  7.986734e-26      5.152461e-25
#                            23    5.406381e-25  5.050457e-24      3.892594e-23
#                            24    1.951978e-24  1.823472e-23      1.424944e-22
#                            25    2.033871e-24  1.899973e-23      1.525403e-22
#                            26    2.297438e-24  2.146188e-23      1.746053e-22
#                            27    3.627762e-24  3.388932e-23      3.576232e-22
# 37                         0     4.445334e-03  3.329315e-02      1.000000e+00
# 38                         0     4.449620e-03  3.347337e-02      1.000000e+00
#                            1     4.449620e-03  3.347337e-02      1.000000e+00

# %% [markdown]
# # Quantification

# %% [markdown]
# ## By Markers

# %%
# %%time

outs, failed = {}, []  # hold results
for i, k in enumerate(self.rna.obs[c_t].unique()):
    if tgdf is not None and k in tgdf.reset_index(1).index.values:
        print(f"{'=' * 80}\n{k}\n ({i + 1}/{len(self.rna.obs[c_t].unique())})"
              f"\n{'=' * 80}\n\n{tgdf.loc[k].iloc[:, :3]}\n\n")
    try:
        outs[k] = self.print_markers(
                k, assign, col_cell_type=c_t, lfc_threshold=2,
                count_threshold=count_threshold, p_threshold=1e-15,
                print_threshold=15, n_top_genes=20)
    except Exception as err:
        failed += [(k, err)]
if len(failed) > 0:
    print(f"Failed: {pd.Series(dict(failed))}")
# Out:
# ================================================================================
# 26
#  (1/39)
# ================================================================================
#
#                                                                                                                                              Name  \
# Rank
# 0                3'-Child09-12-SmInt-Hematopoietic-Myeloid-Mast_cell|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1          3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid-Mast_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2     5'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid-CLC+_Mast_cell|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3                3'-Child04-06-SmInt-Hematopoietic-Myeloid-Mast_cell|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches                                                   Genes
# Rank
# 0            8 / 20   [CD44, KIT, TPSAB1, FOXP1, CPA3, MACIR, FCER1G, CMA1]
# 1            8 / 20  [CD44, KIT, TPSAB1, FOXP1, CPA3, FCER1G, CMA1, CSF2RB]
# 2            7 / 20         [CD44, KIT, TPSAB1, CPA3, FCER1G, CMA1, CSF2RB]
# 3            7 / 20           [CD44, KIT, TPSAB1, CPA3, CSF1, FCER1G, CMA1]
#
#
# ================================================================================
# 32
#  (2/39)
# ================================================================================
#
#                                                                                                                                                   Name  \
# Rank
# 0      3'-Pediatric_IBD-SmInt-Epithelial-epithelial_progenitor_cell-TA|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1         3'-Pediatric_IBD-SmInt-Epithelial-epithelial_progenitor_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2                 5'-GW_trimst-1.5-SmInt-Epithelial-goblet-Goblet_cell|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3                             5'-GW_trimst-1.5-SmInt-Epithelial-goblet|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4                3'-Child04-06-SmInt-Epithelial-mature_enterocytic-Paneth|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5          3'-GW_trimst-1.5-SmInt-Epithelial-mature_enterocytic-Paneth|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6                                 5'-Adult-SmInt-Epithelial-goblet-Goblet_cell|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7                                             5'-Adult-SmInt-Epithelial-goblet|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 8                                                                  Enterocyte_Progenitors-C_06|Enterocyte_Progenitors / shred on cell type and cluster
# 9                             3'-Pediatric_IBD-SmInt-Epithelial-goblet|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 10                3'-Pediatric_IBD-SmInt-Epithelial-goblet-Goblet_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 11                                  3'-Child09-12-SmInt-Epithelial-goblet|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 12                      3'-Child09-12-SmInt-Epithelial-goblet-Goblet_cell|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 13                                3'-GW_trimst-1-SmInt-Epithelial-goblet|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 14                    3'-GW_trimst-1-SmInt-Epithelial-goblet-Goblet_cell|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 15               3'-Child09-12-SmInt-Epithelial-mature_enterocytic-Paneth|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 16                         5'-Adult-SmInt-Epithelial-goblet-BEST2+_Goblet_cell|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 17       3'-Pediatric_IBD-SmInt-Epithelial-Tuft-related-Microfold_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 18             3'-GW_trimst-2-SmInt-Epithelial-mature_enterocytic-Paneth|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 19         3'-Pediatric_IBD-SmInt-Epithelial-mature_enterocytic-Paneth|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 20         3'-Pediatric_IBD-SmInt-Epithelial-goblet-BEST2+_Goblet_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 21                      5'-GW_trimst-1.5-SmInt-Epithelial-Tuft-related|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 22    5'-GW_trimst-1.5-SmInt-Epithelial-Tuft-related-BEST4+_epithelial|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches                                             Genes
# Rank
# 0            7 / 20  [CCL25, MUC1, FAM3D, MYO10, LIMA1, UQCRC1, LCN2]
# 1            6 / 20         [CCL25, MUC1, FAM3D, MYO10, UQCRC1, LCN2]
# 2            6 / 20        [CCL25, MUC2, KLK1, IRF6, SERPINA1, PLAC8]
# 3            6 / 20        [CCL25, MUC2, KLK1, IRF6, SERPINA1, PLAC8]
# 4            5 / 20                 [LYZ, MUC1, KLK1, SERPINA1, LCN2]
# 5            5 / 20                [CCL25, LYZ, KLK1, IRF6, SERPINA1]
# 6            5 / 20           [CCL25, MUC2, KLK1, SERPINA1, MARCKSL1]
# 7            5 / 20           [CCL25, MUC2, KLK1, SERPINA1, MARCKSL1]
# 8            5 / 20                [LYZ, MUC1, FAM3D, SERPINA1, LCN2]
# 9            5 / 20                   [MUC1, MUC2, KLK1, FAM3D, IRF6]
# 10           5 / 20                   [MUC1, MUC2, KLK1, FAM3D, IRF6]
# 11           5 / 20                   [MUC1, MUC2, KLK1, FAM3D, IRF6]
# 12           5 / 20                   [MUC1, MUC2, KLK1, FAM3D, IRF6]
# 13           5 / 20               [CCL25, MUC2, KLK1, IRF6, SERPINA1]
# 14           5 / 20               [CCL25, MUC2, KLK1, IRF6, SERPINA1]
# 15           4 / 20                           [LYZ, MUC1, KLK1, LCN2]
# 16           4 / 20                  [MUC2, KLK1, SERPINA1, MARCKSL1]
# 17           4 / 20                       [LYZ, MUC1, SERPINA1, LCN2]
# 18           4 / 20                      [LYZ, MUC1, MST1R, SERPINA1]
# 19           4 / 20                       [LYZ, MUC1, SERPINA1, LCN2]
# 20           4 / 20                         [MUC1, MUC2, FAM3D, IRF6]
# 21           4 / 20                         [LYZ, KLK1, FAM3D, PLAC8]
# 22           4 / 20                         [LYZ, KLK1, FAM3D, PLAC8]
#
#
# ================================================================================
# 11
#  (3/39)
# ================================================================================
#
#                                                                                                                                              Name  \
# Rank
# 0         5'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-CLC+_Mast_cell|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1         3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-CLC+_Mast_cell|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2     5'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid-CLC+_Mast_cell|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3                3'-Child04-06-SmInt-Hematopoietic-Myeloid-Mast_cell|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4                          5'-Adult-SmInt-Hematopoietic-Myeloid-Mast_cell|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5              3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-Mast_cell|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6                3'-Child09-12-SmInt-Hematopoietic-Myeloid-Mast_cell|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7              5'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-Mast_cell|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 8          3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid-Mast_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches                      Genes
# Rank
# 0             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
# 1             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
# 2             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
# 3             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
# 4             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
# 5             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
# 6             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
# 7             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
# 8             4 / 4  [KIT, TPSAB1, CPA3, CMA1]
#
#
# ================================================================================
# 9
#  (5/39)
# ================================================================================
#
#                                                                                                                                         Name  \
# Rank
# 0     5'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid-Monocytes|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1               3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches                                                    Genes
# Rank
# 0            8 / 18  [LST1, S100A8, APOBR, JAML, TYROBP, HCK, PLAUR, CSF2RA]
# 1            8 / 18   [LST1, S100A8, JAML, TYROBP, HCK, PLAUR, MMP9, CSF2RA]
#
#
# ================================================================================
# 1
#  (6/39)
# ================================================================================
#
#                                                                                                                                   Name  \
# Rank
# 0          3'-Child09-12-SmInt-Hematopoietic-T_cells-Th17|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1     3'-Pediatric_IBD-SmInt-Hematopoietic-T_cells-Tfh|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2           3'-Child04-06-SmInt-Hematopoietic-T_cells-Tfh|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           11 / 20
# 1           11 / 20
# 2           11 / 20
#
#                                                                             Genes
# Rank
# 0     [ETS1, IFITM1, KLRB1, ARHGDIB, CD52, CD3D, BCL2, CD3E, IKZF3, IL7R, GPR183]
# 1        [ETS1, IFITM1, KLRB1, ARHGDIB, CD52, CD3D, TCF7, CD3E, GPR183, CD4, MAF]
# 2       [IFITM1, KLRB1, ARHGDIB, CD52, CD3D, TCF7, CD3E, IKZF3, GPR183, CD4, MAF]
#
#
# ================================================================================
# 7
#  (7/39)
# ================================================================================
#
#                                                                                                                                         Name  \
# Rank
# 0        5'-GW_trimst-2-SmInt-Hematopoietic-B_cells-Immature_B|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1     3'-Child04-06-SmInt-Hematopoietic-B_cells-FCRL4+_Memory_B|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2                       5'-Adult-SmInt-Hematopoietic-B_cells-Naive_B|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3                      5'-Adult-SmInt-Hematopoietic-B_cells-Memory_B|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           12 / 20
# 1           10 / 20
# 2           10 / 20
# 3           10 / 20
#
#                                                                                     Genes
# Rank
# 0     [IRF8, SP110, BIRC3, ARHGDIB, CD79A, CD79B, SP100, BANK1, LTB, CD52, INPP5D, IKZF3]
# 1                   [SP110, CTSH, PTPN1, CD79A, CD79B, BANK1, LTB, CD52, INPP5D, RNASET2]
# 2                      [IRF8, SP110, LBH, ARHGDIB, CD79A, CD79B, SP100, BANK1, LTB, CD52]
# 3                   [IRF8, SP110, CTSH, ARHGDIB, CD79A, CD79B, BANK1, LTB, CD52, RNASET2]
#
#
# ================================================================================
# 8
#  (9/39)
# ================================================================================
#
#                                                                                                                                                        Name  \
# Rank
# 0                                        3'-Pediatric_IBD-SmInt-Mesenchymal|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1                           3'-Pediatric_IBD-SmInt-Mesenchymal-fibroblastic|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2           3'-Child04-06-SmInt-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3     3'-Pediatric_IBD-SmInt-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4           3'-Child09-12-SmInt-Mesenchymal-fibroblastic-Stromal_1_(ADAMDEC1+)|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           10 / 20
# 1           10 / 20
# 2           10 / 20
# 3            9 / 20
# 4            9 / 20
#
#                                                                               Genes
# Rank
# 0     [COL4A1, PDGFRA, COL4A2, PDPN, PDGFRB, CCL11, SERPINF1, COL1A1, GPX3, COL1A2]
# 1     [PDGFRA, COL4A2, PDPN, PDGFRB, CCL11, SERPINF1, CHI3L1, COL1A1, GPX3, COL1A2]
# 2      [PDGFRA, COL4A2, CCL11, IL6ST, SERPINF1, CSF1, CHI3L1, COL1A1, GPX3, COL1A2]
# 3            [PDGFRA, COL4A2, PDGFRB, CCL11, IL6ST, SERPINF1, COL1A1, GPX3, COL1A2]
# 4              [PDGFRA, COL4A2, CCL11, IL6ST, SERPINF1, CSF1, COL1A1, GPX3, COL1A2]
#
#
# ================================================================================
# 6
#  (10/39)
# ================================================================================
#
#                                                                                                                                           Name  \
# Rank
# 0     5'-GW_trimst-2-SmInt-Hematopoietic-T_cells-TRDV2/TRGV9_gdT|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1             5'-GW_trimst-2-SmInt-Hematopoietic-T_cells-NK_cell|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2                     5'-GW_trimst-2-SmInt-Hematopoietic-T_cells|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3         5'-GW_trimst-2-SmInt-Hematopoietic-T_cells-Activated_T|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4             3'-GW_trimst-1-SmInt-Hematopoietic-T_cells-NK_cell|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           16 / 20
# 1           15 / 20
# 2           15 / 20
# 3           15 / 20
# 4           14 / 20
#
#                                                                                                             Genes
# Rank
# 0     [CD44, RUNX3, ETS1, IFITM1, CD69, CXCR4, ARHGDIB, PTPN22, CCL5, GFI1, NKG7, CD3D, CD3E, IKZF3, STAT4, GZMK]
# 1           [CD44, RUNX3, ETS1, IFITM1, CD69, CXCR4, ARHGDIB, PTPN22, CCL5, GFI1, NKG7, CD3E, IKZF3, STAT4, GZMK]
# 2             [CD44, RUNX3, ETS1, CD69, CXCR4, ARHGDIB, PTPN22, CCL5, GFI1, NKG7, CD3D, CD3E, IKZF3, STAT4, GZMK]
# 3           [CD44, RUNX3, ETS1, IFITM1, CD69, CXCR4, ARHGDIB, PTPN22, CCL5, GFI1, NKG7, CD3D, CD3E, IKZF3, STAT4]
# 4                 [CD44, RUNX3, CD69, CXCR4, ARHGDIB, PTPN22, CCL5, NKG7, CD3D, INPP5D, CD3E, IKZF3, STAT4, GZMK]
#
#
# ================================================================================
# 0
#  (11/39)
# ================================================================================
#
#                                                                                                                                                    Name  \
# Rank
# 0                     3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1     3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2           3'-Child09-12-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3     3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells-IgG_plasma_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4           3'-Child04-06-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5                           3'-Child09-12-SmInt-Hematopoietic-Plasma_cells|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches                                                  Genes
# Rank
# 0            8 / 20  [XBP1, KCNN3, RPN1, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 1            8 / 20  [XBP1, KCNN3, RPN1, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 2            7 / 20    [XBP1, KCNN3, CD79A, ZBTB38, IFNAR2, PRDM1, CSF2RB]
# 3            7 / 20        [XBP1, KCNN3, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 4            6 / 20               [XBP1, KCNN3, RPN2, CD79A, IL5RA, PRDM1]
# 5            6 / 20            [XBP1, KCNN3, CD79A, IFNAR2, PRDM1, CSF2RB]
#
#
# ================================================================================
# 2
#  (13/39)
# ================================================================================
#
#                                                                                                                                                 Name  \
# Rank
# 0     3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1         3'-GW_trimst-1-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2         5'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3           3'-Child04-06-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4         3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5     5'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6           3'-Child09-12-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7                           3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           17 / 20
# 1           17 / 20
# 2           17 / 20
# 3           16 / 20
# 4           16 / 20
# 5           16 / 20
# 6           14 / 20
# 7           14 / 20
#
#                                                                                                                   Genes
# Rank
# 0         [CD14, DAB2, IL10RA, LYZ, AIF1, MRC1, FCGRT, MAFB, PLTP, CD163, CD4, RNASET2, CSF1R, APOE, MAF, NAIP, FCER1G]
# 1     [CD14, DAB2, IL10RA, AIF1, MRC1, FCGRT, LYVE1, MAFB, PLTP, RNASE1, CD163, CD4, RNASET2, CSF1R, MAF, NAIP, FCER1G]
# 2     [CD14, DAB2, IL10RA, AIF1, MRC1, FCGRT, LYVE1, MAFB, PLTP, RNASE1, CD163, CD4, RNASET2, CSF1R, MAF, NAIP, FCER1G]
# 3              [CD14, DAB2, IL10RA, LYZ, AIF1, MRC1, FCGRT, MAFB, PLTP, CD163, CD4, RNASET2, CSF1R, APOE, NAIP, FCER1G]
# 4            [CD14, DAB2, IL10RA, AIF1, MRC1, LYVE1, MAFB, PLTP, RNASE1, CD163, CD4, RNASET2, CSF1R, MAF, NAIP, FCER1G]
# 5           [CD14, DAB2, IL10RA, AIF1, MRC1, FCGRT, LYVE1, MAFB, RNASE1, CD163, CD4, RNASET2, CSF1R, MAF, NAIP, FCER1G]
# 6                          [CD14, DAB2, LYZ, AIF1, MRC1, FCGRT, MAFB, RNASE1, CD163, CD4, RNASET2, CSF1R, NAIP, FCER1G]
# 7                        [CD14, IL10RA, LYZ, AIF1, MRC1, LYVE1, MAFB, RNASE1, CD163, CD4, RNASET2, CSF1R, NAIP, FCER1G]
#
#
# ================================================================================
# 24
#  (14/39)
# ================================================================================
#
#                                                                                                                                         Name  \
# Rank
# 0              3'-GW_trimst-1-SmInt-Hematopoietic-Myeloid-cDC1|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1     5'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid-Monocytes|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2               3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3               3'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4          3'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid-cDC2|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5                          5'-Adult-SmInt-Hematopoietic-Myeloid-cDC2|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6                   3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           10 / 20
# 1           10 / 20
# 2           10 / 20
# 3            9 / 20
# 4            9 / 20
# 5            9 / 20
# 6            9 / 20
#
#                                                                      Genes
# Rank
# 0      [SPI1, LST1, IDO1, APOBR, JAML, HCK, PTPN22, CLEC9A, LRRK2, CSF2RA]
# 1     [SPI1, LST1, S100A8, APOBR, JAML, TYROBP, HCK, PLAUR, LRRK2, CSF2RA]
# 2       [SPI1, LST1, IDO1, S100A8, JAML, TYROBP, HCK, PLAUR, MMP9, CSF2RA]
# 3            [SPI1, LAMP3, LST1, S100A8, APOBR, JAML, TYROBP, HCK, CSF2RA]
# 4            [SPI1, LAMP3, LST1, APOBR, JAML, TYROBP, METRNL, HCK, CSF2RA]
# 5              [SPI1, LAMP3, LST1, IDO1, JAML, TYROBP, HCK, LRRK2, CSF2RA]
# 6             [SPI1, LST1, JAML, TYROBP, HCK, PLAUR, CLEC9A, MMP9, CSF2RA]
#
#
# ================================================================================
# 15
#  (15/39)
# ================================================================================
#
#                                                                                                                                                 Name  \
# Rank
# 0           3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid-Macrophages|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1                        3'-Child09-12-SmInt-Hematopoietic-Myeloid-cDC2|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2                                  5'-Adult-SmInt-Hematopoietic-Myeloid-cDC2|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3               3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-Macrophages|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4     3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5                      5'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-cDC2|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6                           3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7                           5'-GW_trimst-2-SmInt-Hematopoietic-Myeloid|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 8                       5'-GW_trimst-1.5-SmInt-Hematopoietic-Myeloid|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 9               5'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-Macrophages|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 10                      3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 11                3'-Child04-06-SmInt-Hematopoietic-Myeloid-Macrophages|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 12                          5'-Adult-SmInt-Hematopoietic-Myeloid-Macrophages|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 13          3'-Child04-06-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 14                                      5'-Adult-SmInt-Hematopoietic-Myeloid|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 15                                  5'-GW_trimst-2-SmInt-Hematopoietic|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 16                            3'-Child09-12-SmInt-Hematopoietic-Myeloid|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 17                            3'-Child04-06-SmInt-Hematopoietic-Myeloid|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 18                3'-Child09-12-SmInt-Hematopoietic-Myeloid-Macrophages|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 19                  3'-Child04-06-SmInt-Hematopoietic-Myeloid-Monocytes|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 20                 3'-Pediatric_IBD-SmInt-Hematopoietic-Myeloid-cDC2|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 21                     3'-GW_trimst-2-SmInt-Hematopoietic-Myeloid-cDC2|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 22                    5'-Adult-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 23          3'-Child09-12-SmInt-Hematopoietic-Myeloid-LYVE1+_Macrophage|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 24                       3'-Child04-06-SmInt-Hematopoietic-Myeloid-cDC2|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           16 / 20
# 1           15 / 20
# 2           15 / 20
# 3           15 / 20
# 4           15 / 20
# 5           15 / 20
# 6           15 / 20
# 7           15 / 20
# 8           15 / 20
# 9           15 / 20
# 10          15 / 20
# 11          14 / 20
# 12          14 / 20
# 13          14 / 20
# 14          14 / 20
# 15          14 / 20
# 16          14 / 20
# 17          14 / 20
# 18          13 / 20
# 19          13 / 20
# 20          13 / 20
# 21          13 / 20
# 22          13 / 20
# 23          13 / 20
# 24          13 / 20
#
#                                                                                                         Genes
# Rank
# 0     [SPI1, IFNGR1, LYZ, AIF1, MRC1, CTSH, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 1            [SPI1, IFNGR1, LYZ, AIF1, MRC1, CTSH, JAML, CLEC4A, HCK, MAFB, CD1C, CD4, CSF1R, CSF2RA, FCER1G]
# 2             [SPI1, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD1C, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 3           [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 4           [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 5          [SPI1, IFNGR1, IL10RA, LYZ, AIF1, CTSH, JAML, CLEC4A, HCK, CD1C, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 6           [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 7           [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 8          [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD1C, CD163, CSF1R, CSF2RA, NAIP, FCER1G]
# 9           [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 10            [SPI1, LYZ, AIF1, MRC1, CTSH, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 11                [IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 12                  [SPI1, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 13                [IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 14                  [SPI1, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 15               [SPI1, IL10RA, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CSF1R, CSF2RA, NAIP, FCER1G]
# 16                  [SPI1, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 17                  [SPI1, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 18                         [SPI1, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 19                       [SPI1, LYZ, AIF1, MRC1, JAML, CLEC4A, HCK, MAFB, CD163, CSF1R, CSF2RA, NAIP, FCER1G]
# 20                         [SPI1, LYZ, AIF1, MRC1, CTSH, JAML, CLEC4A, HCK, CD1C, CD4, CSF1R, CSF2RA, FCER1G]
# 21                       [SPI1, IL10RA, LYZ, AIF1, CTSH, JAML, CLEC4A, HCK, CD1C, CD4, CSF1R, CSF2RA, FCER1G]
# 22                          [SPI1, LYZ, AIF1, MRC1, HCK, MAFB, CD1C, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 23                          [SPI1, LYZ, AIF1, MRC1, JAML, HCK, MAFB, CD163, CD4, CSF1R, CSF2RA, NAIP, FCER1G]
# 24                         [SPI1, LYZ, AIF1, MRC1, CTSH, JAML, CLEC4A, HCK, CD1C, CD4, CSF1R, CSF2RA, FCER1G]
#
#
# ================================================================================
# 25
#  (17/39)
# ================================================================================
#
#                                                                                                                                   Name  \
# Rank
# 0         3'-GW_trimst-1.5-SmInt-Hematopoietic-T_cells|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1                 3'-GW_trimst-1.5-SmInt-Hematopoietic|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2             5'-GW_trimst-2-SmInt-Hematopoietic-T_cells|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3     3'-GW_trimst-1-SmInt-Hematopoietic-T_cells-NK_cell|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4               5'-Adult-SmInt-Hematopoietic-T_cells-TRGV2_gdT|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           16 / 20
# 1           15 / 20
# 2           15 / 20
# 3           14 / 20
# 4           14 / 20
#
#                                                                                                           Genes
# Rank
# 0     [KLRB1, ARHGDIB, KLRC1, CCL5, MATK, NKG7, GNLY, CD52, INPP5D, CD3D, TCF7, PLAC8, CD3E, STAT4, IL7R, GZMB]
# 1           [KLRB1, ARHGDIB, KLRC1, CCL5, MATK, NKG7, GNLY, CD52, INPP5D, CD3D, PLAC8, CD3E, STAT4, IL7R, GZMB]
# 2             [ETS1, KLRB1, ARHGDIB, KLRC1, CCL5, MATK, NKG7, GNLY, CD52, CD3D, PLAC8, CD3E, STAT4, IL7R, GZMB]
# 3                 [KLRB1, ARHGDIB, KLRC1, CCL5, MATK, NKG7, GNLY, CD52, INPP5D, CD3D, PLAC8, CD3E, STAT4, GZMB]
# 4                  [ETS1, IL10RA, KLRB1, ARHGDIB, KLRC1, CCL5, NKG7, GNLY, CD52, CD3D, CD3E, STAT4, IL7R, GZMB]
#
#
# ================================================================================
# 20
#  (18/39)
# ================================================================================
#
#                                                                                                                                                   Name  \
# Rank
# 0                                         3'-Child09-12-SmInt-Endothelial|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1           3'-Child04-06-SmInt-Mesenchymal-fibroblastic-Stromal_2_(NPY+)|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2                                       3'-GW_trimst-2-SmInt-Endothelial|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3      3'-GW_trimst-2-SmInt-Endothelial-blood_vessel_EC-venous_capillary|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4           3'-Child09-12-SmInt-Mesenchymal-fibroblastic-Stromal_2_(NPY+)|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5                                   3'-Pediatric_IBD-SmInt-Endothelial|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6                                       5'-GW_trimst-2-SmInt-Endothelial|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7     3'-Pediatric_IBD-SmInt-Mesenchymal-fibroblastic-Stromal_2_(NPY+)|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0            8 / 20
# 1            8 / 20
# 2            8 / 20
# 3            8 / 20
# 4            8 / 20
# 5            8 / 20
# 6            8 / 20
# 7            8 / 20
#
#                                                               Genes
# Rank
# 0          [COL4A1, IGFBP7, IFITM3, LYVE1, IL33, CD34, FLT4, PROX1]
# 1     [COL4A1, IGFBP7, COL4A2, PDPN, IFITM3, CDH13, COL1A1, COL1A2]
# 2          [IGFBP7, UACA, LYVE1, IL33, CD34, MARCKSL1, FLT4, PROX1]
# 3        [COL4A1, IGFBP7, UACA, COL4A2, IL33, CD34, MARCKSL1, FLT4]
# 4     [COL4A1, IGFBP7, COL4A2, PDPN, IFITM3, CDH13, COL1A1, COL1A2]
# 5         [COL4A1, IGFBP7, COL4A2, IFITM3, LYVE1, IL33, CD34, FLT4]
# 6         [COL4A1, IGFBP7, UACA, LYVE1, IL33, CD34, MARCKSL1, FLT4]
# 7     [COL4A1, IGFBP7, COL4A2, PDPN, IFITM3, CDH13, COL1A1, COL1A2]
#
#
# ================================================================================
# 5
#  (19/39)
# ================================================================================
#
#                                                                                                                                                        Name  \
# Rank
# 0                        3'-Pediatric_IBD-SmInt-Endothelial-blood_vessel_EC|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1                                        3'-Pediatric_IBD-SmInt-Endothelial|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2     3'-Pediatric_IBD-SmInt-Endothelial-blood_vessel_EC-arterial_capillary|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3                            3'-GW_trimst-2-SmInt-Endothelial-blood_vessel_EC|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4                              3'-Child04-06-SmInt-Endothelial-blood_vessel_EC|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5                                            5'-GW_trimst-2-SmInt-Endothelial|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6                            5'-GW_trimst-2-SmInt-Endothelial-blood_vessel_EC|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7           3'-GW_trimst-2-SmInt-Endothelial-blood_vessel_EC-venous_capillary|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 8                                              3'-Child04-06-SmInt-Endothelial|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 9      3'-GW_trimst-1.5-SmInt-Endothelial-blood_vessel_EC-Fetal_arterial_EC|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 10          3'-Child04-06-SmInt-Endothelial-blood_vessel_EC-arterial_capillary|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 11                       3'-GW_trimst-1.5-SmInt-Endothelial-blood_vessel_EC|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 12          5'-GW_trimst-2-SmInt-Endothelial-blood_vessel_EC-venous_capillary|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 13                                       3'-GW_trimst-1.5-SmInt-Endothelial|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 14          3'-Child04-06-SmInt-Endothelial-blood_vessel_EC-Mature_arterial_EC|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 15     5'-GW_trimst-1.5-SmInt-Endothelial-blood_vessel_EC-Fetal_arterial_EC|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 16    3'-Pediatric_IBD-SmInt-Endothelial-blood_vessel_EC-Mature_arterial_EC|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 17                             3'-Child09-12-SmInt-Endothelial-blood_vessel_EC|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 18                                             3'-Child09-12-SmInt-Endothelial|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 19                       5'-GW_trimst-1.5-SmInt-Endothelial-blood_vessel_EC|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 20                                           3'-GW_trimst-2-SmInt-Endothelial|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 21          3'-Child09-12-SmInt-Endothelial-blood_vessel_EC-arterial_capillary|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           12 / 20
# 1           12 / 20
# 2           11 / 20
# 3           11 / 20
# 4           11 / 20
# 5           11 / 20
# 6           11 / 20
# 7           10 / 20
# 8           10 / 20
# 9           10 / 20
# 10          10 / 20
# 11          10 / 20
# 12          10 / 20
# 13          10 / 20
# 14           9 / 20
# 15           9 / 20
# 16           9 / 20
# 17           9 / 20
# 18           9 / 20
# 19           9 / 20
# 20           9 / 20
# 21           9 / 20
#
#                                                                                        Genes
# Rank
# 0     [COL4A1, IGFBP7, COL4A2, AQP1, IFITM3, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 1     [COL4A1, IGFBP7, COL4A2, AQP1, IFITM3, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 2           [COL4A1, IGFBP7, COL4A2, AQP1, IFITM3, IL3RA, PODXL, ADAM15, RNASE1, CD34, JAM2]
# 3               [COL4A1, IGFBP7, UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 4           [COL4A1, IGFBP7, COL4A2, IFITM3, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 5               [COL4A1, IGFBP7, UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 6               [COL4A1, IGFBP7, UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 7                   [COL4A1, IGFBP7, UACA, COL4A2, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34]
# 8                   [COL4A1, IGFBP7, IFITM3, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 9                        [UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, DUSP1, CD34, JAM2]
# 10                [COL4A1, IGFBP7, COL4A2, IFITM3, IL3RA, PODXL, ADAM15, RNASE1, CD34, JAM2]
# 11                      [IGFBP7, UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 12                  [COL4A1, IGFBP7, COL4A2, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 13                      [IGFBP7, UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 14                            [AQP1, IFITM3, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 15                              [UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 16                             [UACA, AQP1, IFITM3, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 17                          [COL4A1, IGFBP7, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 18                          [COL4A1, IGFBP7, IFITM3, IL3RA, PODXL, IL33, RNASE1, CD34, JAM2]
# 19                              [UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34, JAM2]
# 20                            [IGFBP7, UACA, AQP1, IL3RA, PODXL, ADAM15, IL33, RNASE1, CD34]
# 21                        [COL4A1, IGFBP7, COL4A2, IL3RA, PODXL, ADAM15, RNASE1, CD34, JAM2]
#
#
# ================================================================================
# 23
#  (20/39)
# ================================================================================
#
#                                                                                                                                                     Name  \
# Rank
# 0                    3'-Child09-12-SmInt-Mesenchymal-myocytic-myofibroblast|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1                                  3'-Child09-12-SmInt-Mesenchymal-myocytic|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2              3'-Pediatric_IBD-SmInt-Mesenchymal-myocytic-myofibroblast|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3                            3'-Pediatric_IBD-SmInt-Mesenchymal-myocytic|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4                    3'-Child04-06-SmInt-Mesenchymal-myocytic-myofibroblast|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5                                  3'-Child04-06-SmInt-Mesenchymal-myocytic|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6               5'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7                                            5'-Adult-SmInt-Mesenchymal-myocytic|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 8                                3'-GW_trimst-2-SmInt-Mesenchymal-myocytic|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 9                   3'-GW_trimst-2-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 10                    5'-Adult-SmInt-Mesenchymal-myocytic-myofibroblast_(RSPO2+)|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 11                  5'-GW_trimst-2-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 12                           3'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 13              3'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 14                  3'-GW_trimst-1-SmInt-Mesenchymal-myocytic-SMC_(PLPP2+)|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 15                             5'-Adult-SmInt-Mesenchymal-myocytic-myofibroblast|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 16            5'-GW_trimst-2-SmInt-Mesenchymal-myocytic-SMC_(PART1/CAPN3+)|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 17                               3'-GW_trimst-1-SmInt-Mesenchymal-myocytic|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 18                           5'-GW_trimst-1.5-SmInt-Mesenchymal-myocytic|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 19                               5'-GW_trimst-2-SmInt-Mesenchymal-myocytic|GW_trimst-2 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 20                                        3'-GW_trimst-1-SmInt-Mesenchymal|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 21          3'-Child09-12-SmInt-Mesenchymal-myocytic-myofibroblast_(RSPO2+)|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 22    3'-Pediatric_IBD-SmInt-Mesenchymal-myocytic-myofibroblast_(RSPO2+)|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           17 / 20
# 1           17 / 20
# 2           17 / 20
# 3           17 / 20
# 4           17 / 20
# 5           17 / 20
# 6           17 / 20
# 7           16 / 20
# 8           16 / 20
# 9           16 / 20
# 10          15 / 20
# 11          15 / 20
# 12          15 / 20
# 13          15 / 20
# 14          15 / 20
# 15          14 / 20
# 16          14 / 20
# 17          14 / 20
# 18          14 / 20
# 19          14 / 20
# 20          14 / 20
# 21          13 / 20
# 22          13 / 20
#
#                                                                                                                  Genes
# Rank
# 0     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 1     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 2     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 3     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 4     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 5     [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, COL1A1, COL1A2, MYLK]
# 6        [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, ENAH, NPNT, TAGLN, MYLK]
# 7                [COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, ENAH, NPNT, TAGLN, MYLK]
# 8               [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, NPNT, TAGLN, MYLK]
# 9               [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, NPNT, TAGLN, MYLK]
# 10                     [COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 11                    [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 12                    [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, MYLK]
# 13                    [COL4A1, COL4A2, PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, MYLK]
# 14                    [COL4A1, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, ENAH, NPNT, TAGLN, MYLK]
# 15                         [COL4A2, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, NPNT, TAGLN, COL1A1, MYLK]
# 16                             [PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 17                          [COL4A1, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, ENAH, TAGLN, MYLK]
# 18                            [ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, ENAH, NPNT, TAGLN, MYLK]
# 19                         [COL4A2, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, LPP, ACTA2, ENAH, TAGLN, COL1A1, MYLK]
# 20                    [COL4A1, COL4A2, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, ACTA2, TAGLN, COL1A1, COL1A2, MYLK]
# 21                                   [PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, TAGLN, MYLK]
# 22                                   [PLN, ACTG2, RGS5, DES, FLNA, CNN1, MYH11, CSRP1, GREM1, LPP, ACTA2, TAGLN, MYLK]
#
#
# ================================================================================
# 17
#  (21/39)
# ================================================================================
#
#                                                                                                                                            Name  \
# Rank
# 0                                3'-GW_trimst-1-SmInt-Mesenchymal|GW_trimst-1 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1           3'-Child09-12-SmInt-Mesenchymal-myocytic-myofibroblast|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2                         3'-Child09-12-SmInt-Mesenchymal-myocytic|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3     3'-Pediatric_IBD-SmInt-Mesenchymal-myocytic-myofibroblast|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4                   3'-Pediatric_IBD-SmInt-Mesenchymal-myocytic|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5           3'-Child04-06-SmInt-Mesenchymal-myocytic-myofibroblast|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6                         3'-Child04-06-SmInt-Mesenchymal-myocytic|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7                  3'-Pediatric_IBD-SmInt-Mesenchymal-Pericytes|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0            9 / 20
# 1            8 / 20
# 2            8 / 20
# 3            8 / 20
# 4            8 / 20
# 5            8 / 20
# 6            8 / 20
# 7            8 / 20
#
#                                                                   Genes
# Rank
# 0     [COL4A1, IGFBP7, COL4A2, DES, CNN1, MYH11, CSRP1, COL1A1, COL1A2]
# 1             [COL4A1, COL4A2, DES, CNN1, MYH11, CSRP1, COL1A1, COL1A2]
# 2             [COL4A1, COL4A2, DES, CNN1, MYH11, CSRP1, COL1A1, COL1A2]
# 3             [COL4A1, COL4A2, DES, CNN1, MYH11, CSRP1, COL1A1, COL1A2]
# 4             [COL4A1, COL4A2, DES, CNN1, MYH11, CSRP1, COL1A1, COL1A2]
# 5             [COL4A1, COL4A2, DES, CNN1, MYH11, CSRP1, COL1A1, COL1A2]
# 6             [COL4A1, COL4A2, DES, CNN1, MYH11, CSRP1, COL1A1, COL1A2]
# 7           [COL4A1, IGFBP7, COL4A2, MYH11, DLC1, COL1A1, GPX3, COL1A2]
#
#
# ================================================================================
# 28
#  (22/39)
# ================================================================================
#
#                                                                                                                                                    Name  \
# Rank
# 0                     3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1     3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2           3'-Child09-12-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3     3'-Pediatric_IBD-SmInt-Hematopoietic-Plasma_cells-IgG_plasma_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 4                           3'-Child09-12-SmInt-Hematopoietic-Plasma_cells|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 5           3'-Child04-06-SmInt-Hematopoietic-Plasma_cells-IgM_plasma_cell|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 6           3'-Child09-12-SmInt-Hematopoietic-Plasma_cells-IgG_plasma_cell|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 7                                     5'-Adult-SmInt-Hematopoietic-Plasma_cells|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 8                     5'-Adult-SmInt-Hematopoietic-Plasma_cells-IgA_plasma_cell|Adult / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches                                                  Genes
# Rank
# 0            8 / 20  [XBP1, KCNN3, RPN1, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 1            8 / 20  [XBP1, KCNN3, RPN1, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 2            7 / 20    [XBP1, KCNN3, CD79A, ZBTB38, IFNAR2, PRDM1, CSF2RB]
# 3            7 / 20        [XBP1, KCNN3, RPN2, CD79A, ATF4, IFNAR2, PRDM1]
# 4            6 / 20            [XBP1, KCNN3, CD79A, IFNAR2, PRDM1, CSF2RB]
# 5            6 / 20                [XBP1, KCNN3, KLK1, RPN2, CD79A, PRDM1]
# 6            5 / 20                     [XBP1, RPN2, CD79A, IFNAR2, PRDM1]
# 7            5 / 20                   [XBP1, CD79A, ZBTB38, PRDM1, CSF2RB]
# 8            5 / 20                   [XBP1, CD79A, ZBTB38, PRDM1, CSF2RB]
#
#
# ================================================================================
# 12
#  (24/39)
# ================================================================================
#
#                                                                                                                                                               Name  \
# Rank
# 0                      3'-Pediatric_IBD-SmInt-Hematopoietic-B_cells-Cycling_B_cell|Pediatric_IBD / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 1                            3'-Child04-06-SmInt-Hematopoietic-B_cells-Cycling_B_cell|Child04-06 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 2                            3'-Child09-12-SmInt-Hematopoietic-B_cells-Cycling_B_cell|Child09-12 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
# 3     5'-GW_trimst-1.5-SmInt-Mesenchymal-immature_mesenchymal_cell-cycling_stromal|GW_trimst-1.5 / Celltypes from developing, pediatric, Crohn's, & adult GI tract
#
#      Marker Matches  \
# Rank
# 0           11 / 20
# 1           11 / 20
# 2           11 / 20
# 3            8 / 20
#
#                                                                             Genes
# Rank
# 0     [H2AX, SNRPD1, TUBA1B, HMGB1, TK1, HMGB2, SNRPG, RANBP1, TOP2A, TFDP1, DUT]
# 1     [H2AX, SNRPD1, TUBA1B, HMGB1, TK1, HMGB2, SNRPG, RANBP1, TOP2A, TFDP1, DUT]
# 2     [H2AX, SNRPD1, TUBA1B, HMGB1, TK1, HMGB2, SNRPG, RANBP1, TOP2A, TFDP1, DUT]
# 3                           [H2AX, TUBA1B, HMGB1, TK1, HMGB2, RANBP1, TOP2A, DUT]

# %% [markdown]
# ## By Specific Genes

# %%
# %%time

ggg = pd.DataFrame(["CDKN1A", "CDKN2A", "TP53", "PLAUR", "IL6ST"])[
    0].to_frame("Gene").assign(Annotation="Senescence").set_index("Gene")
outs_bg, failed = {}, []  # hold results
for i, k in enumerate(self.rna.obs[c_t].unique()):
    outs_bg[k] = self.print_markers(
        k, ggg, col_cell_type=c_t, lfc_threshold=None, print_threshold=0,
        count_threshold=count_threshold, p_threshold=None, n_top_genes=None)
if len(failed) > 0:
    print(f"Failed: {pd.Series(dict(failed))}")

# %% [markdown]
# ## Write

# %%
for i, x in enumerate([outs, outs_bg]):
    quant = {}
    for k in outs:
        percs_exp, n_exp = x[k][1].copy(), x[k][2].copy()
        quant[k] = pd.concat([
            x.rename_axis("Measure", axis=1).stack() for x in [
                percs_exp.rename_axis("Cell Types", axis=1).stack().replace(
                    "", np.nan).dropna().to_frame("n_exp"), n_exp.set_index(
                        "Cell Types", append=True).rename({
                            k: "Cluster"}, axis=1)]], keys=[
                                "quantification", "representation"]).unstack(
                                    0).unstack(-1).dropna(how="all", axis=1)
    quant = pd.concat(quant, names=["Cluster"])
    if out_dir:
        suf = "" if i == 0 else "_" + "_".join(ggg.reset_index(
            ).Gene.unique().to_list())  # file suffix if by gene
        q_file = os.path.join(
            out_dir, "quantification",
            f"{self._library_id}__{c_t}_quantification_annotation{suf}.xlsx")
        print(f"Writing to {q_file}")
        quant.to_excel(q_file)

# %% [markdown]
# # View

# %% [markdown]
# ## ToppGene/Quantifications

# %%
key_cluster = "34"
output = outs  # see "by markers" version
# output = outs_bg  # see "by specific genes" version

if tgdf is not None and key_cluster in tgdf.reset_index(1).index.values:
    print(f"{'=' * 80}\n\n{key_cluster}\n\n"
          f"{tgdf.loc[key_cluster].iloc[:, :-3]}")
_, percs_exp, n_exp, genes, msg = outs[key_cluster]
n_exp = n_exp.copy().set_index("Cell Types", append=True)
print(percs_exp.applymap(lambda x: x if x == "" else str(
    int(x)) + "%").stack().replace("", np.nan).dropna().sort_values(
            ascending=False).head(20))
print(f"{genes}\n\n{n_exp.applymap(int)}\n\n{msg}")
print(f"\n\nN = {sum(self.rna.obs[c_t] == k)}\n\n")
percs_exp.applymap(lambda x: x if x == "" else str(int(x)) + "%")
# Out:
# Gene
# NACA      CLP                            99%
# CFB       Mesothelium (PRG4+)            95%
# SLC39A8   Mesothelium (PRG4+)            94%
#           BEST2+ Goblet cell             94%
# COL1A1    Glia 1 (DHH+)                  92%
#           Neural                         92%
#           Stromal 3 (C7+)                92%
# AQP1      Glia 2 (ELN+)                  89%
#           Endothelial                    89%
# HSP90AA1  ILC1                           88%
# SNX3      cDC1                           85%
# SORBS2    Adult Glia                     79%
#           Contractile pericyte (PLN+)    79%
#           Mesenchymal                    79%
#           arterial capillary             79%
# FOSL2     TRGV4 gdT                      72%
#           Monocytes                      72%
# DAB2      Myeloid                        71%
#           LYVE1+ Macrophage              71%
# HSPA1B    myofibroblast (RSPO2+)         64%
# dtype: object
# group
# Adult Glia                              SORBS2
# BEST2+ Goblet cell                     SLC39A8
# CLP                                       NACA
# Contractile pericyte (PLN+)             SORBS2
# Endothelial                               AQP1
# Glia 1 (DHH+)                           COL1A1
# Glia 2 (ELN+)                             AQP1
# Glia 3 (BCAN+)                         TPD52L1
# ILC1                                  HSP90AA1
# LYVE1+ Macrophage                         DAB2
# Mature venous EC                       TPD52L1
# Mesenchymal                             SORBS2
# Mesothelium (PRG4+)               SLC39A8, CFB
# Mesothelium (RGS5+)                      PODXL
# Monocytes                                FOSL2
# Myeloid                                   DAB2
# Neural                         COL1A1, TPD52L1
# Stromal 3 (C7+)                         COL1A1
# TRGV4 gdT                                FOSL2
# arterial capillary                      SORBS2
# cDC1                                      SNX3
# myofibroblast (RSPO2+)                  HSPA1B
# dtype: object
#
#                                                                                     34  \
# Gene     Cell Types
# SLC39A8  BEST2+ Goblet cell, Mesothelium (PRG4+)                                   105
# PODXL    Mesothelium (RGS5+)                                                        64
# TPD52L1  Mature venous EC, Glia 3 (BCAN+), Neural                                   56
# SORBS2   Contractile pericyte (PLN+), arterial capillary, Adult Glia, Mesenchymal   88
# CFB      Mesothelium (PRG4+)                                                       106
# DAB2     LYVE1+ Macrophage, Myeloid                                                 79
# FOSL2    TRGV4 gdT, Monocytes                                                       80
# HSPA1B   myofibroblast (RSPO2+)                                                     72
# AQP1     Glia 2 (ELN+), Endothelial                                                 99
# COL1A1   Stromal 3 (C7+), Glia 1 (DHH+), Neural                                    103
# HSP90AA1 ILC1                                                                       98
# SNX3     cDC1                                                                       95
# NACA     CLP                                                                       110
#
#                                                                                     Other  \
# Gene     Cell Types
# SLC39A8  BEST2+ Goblet cell, Mesothelium (PRG4+)                                    14387
# PODXL    Mesothelium (RGS5+)                                                         9371
# TPD52L1  Mature venous EC, Glia 3 (BCAN+), Neural                                    8480
# SORBS2   Contractile pericyte (PLN+), arterial capillary, Adult Glia, Mesenchymal   22656
# CFB      Mesothelium (PRG4+)                                                        36757
# DAB2     LYVE1+ Macrophage, Myeloid                                                 28151
# FOSL2    TRGV4 gdT, Monocytes                                                       45447
# HSPA1B   myofibroblast (RSPO2+)                                                     42012
# AQP1     Glia 2 (ELN+), Endothelial                                                 66068
# COL1A1   Stromal 3 (C7+), Glia 1 (DHH+), Neural                                     83499
# HSP90AA1 ILC1                                                                       93598
# SNX3     cDC1                                                                       94779
# NACA     CLP                                                                       170907
#
#                                                                                     Total  \
# Gene     Cell Types
# SLC39A8  BEST2+ Goblet cell, Mesothelium (PRG4+)                                    14492
# PODXL    Mesothelium (RGS5+)                                                         9435
# TPD52L1  Mature venous EC, Glia 3 (BCAN+), Neural                                    8536
# SORBS2   Contractile pericyte (PLN+), arterial capillary, Adult Glia, Mesenchymal   22744
# CFB      Mesothelium (PRG4+)                                                        36863
# DAB2     LYVE1+ Macrophage, Myeloid                                                 28230
# FOSL2    TRGV4 gdT, Monocytes                                                       45527
# HSPA1B   myofibroblast (RSPO2+)                                                     42084
# AQP1     Glia 2 (ELN+), Endothelial                                                 66167
# COL1A1   Stromal 3 (C7+), Glia 1 (DHH+), Neural                                     83602
# HSP90AA1 ILC1                                                                       93696
# SNX3     cDC1                                                                       94874
# NACA     CLP                                                                       171017
#
#                                                                                    Percent_Total
# Gene     Cell Types
# SLC39A8  BEST2+ Goblet cell, Mesothelium (PRG4+)                                               0
# PODXL    Mesothelium (RGS5+)                                                                   0
# TPD52L1  Mature venous EC, Glia 3 (BCAN+), Neural                                              0
# SORBS2   Contractile pericyte (PLN+), arterial capillary, Adult Glia, Mesenchymal              0
# CFB      Mesothelium (PRG4+)                                                                   0
# DAB2     LYVE1+ Macrophage, Myeloid                                                            0
# FOSL2    TRGV4 gdT, Monocytes                                                                  0
# HSPA1B   myofibroblast (RSPO2+)                                                                0
# AQP1     Glia 2 (ELN+), Endothelial                                                            0
# COL1A1   Stromal 3 (C7+), Glia 1 (DHH+), Neural                                                0
# HSP90AA1 ILC1                                                                                  0
# SNX3     cDC1                                                                                  0
# NACA     CLP                                                                                   0
#
# 99% NACA+; 95% CFB+; 94% SLC39A8+; 92% COL1A1+; 89% AQP1+; 88% HSP90AA1+; 85% SNX3+; 79% SORBS2+; 72% FOSL2+; 71% DAB2+; 64% HSPA1B+; 57% PODXL+; 50% TPD52L1+ (>=1 counts)
#
#
# N = 1899
#          Adult Glia BEST2+ Goblet cell  CLP Contractile pericyte (PLN+)  \
# Gene
# AQP1
# CFB
# COL1A1
# DAB2
# FOSL2
# HSP90AA1
# HSPA1B
# NACA                                    99%
# PODXL
# SLC39A8                            94%
# SNX3
# SORBS2          79%                                                 79%
# TPD52L1
#
#          Endothelial Glia 1 (DHH+) Glia 2 (ELN+) Glia 3 (BCAN+) ILC1  \
# Gene
# AQP1             89%                         89%
# CFB
# COL1A1                         92%
# DAB2
# FOSL2
# HSP90AA1                                                         88%
# HSPA1B
# NACA
# PODXL
# SLC39A8
# SNX3
# SORBS2
# TPD52L1                                                     50%
#
#          LYVE1+ Macrophage Mature venous EC Mesenchymal Mesothelium (PRG4+)  \
# Gene
# AQP1
# CFB                                                                     95%
# COL1A1
# DAB2                   71%
# FOSL2
# HSP90AA1
# HSPA1B
# NACA
# PODXL
# SLC39A8                                                                 94%
# SNX3
# SORBS2                                              79%
# TPD52L1                                 50%
#
#          Mesothelium (RGS5+) Monocytes Myeloid Neural Stromal 3 (C7+)  \
# Gene
# AQP1
# CFB
# COL1A1                                            92%             92%
# DAB2                                       71%
# FOSL2                              72%
# HSP90AA1
# HSPA1B
# NACA
# PODXL                    57%
# SLC39A8
# SNX3
# SORBS2
# TPD52L1                                           50%
#
#          TRGV4 gdT arterial capillary cDC1 myofibroblast (RSPO2+)
# Gene
# AQP1
# CFB
# COL1A1
# DAB2
# FOSL2          72%
# HSP90AA1
# HSPA1B                                                        64%
# NACA
# PODXL
# SLC39A8
# SNX3                                   85%
# SORBS2                            79%
# TPD52L1

# %% [markdown]
# ## Plotting

# %% [markdown]
# ## Specific to Subsets of Cell Types

# %%
# comp = ["0", "5", "8", "10", "18", "20", "34"]
comp = ["2", "7", "11", "21", "28"]
count_threshold = 1
key_cluster = "2"
_, percs_exp, n_exp, genes, msg = self.print_markers(
    key_cluster, assign, col_cell_type=c_t, lfc_threshold=None,
    key_compare=comp, count_threshold=count_threshold, p_threshold=1,
    n_top_genes=list(assign[assign.Lump == "Epithelial"].index.intersection(
        self.rna.var_names)) + ["TP53", "PLAUR"])
n_exp = n_exp.copy().set_index("Cell Types", append=True)
print(f"{genes}\n\n{n_exp.applymap(int)}\n\n{msg}")
percs_exp.applymap(lambda x: x if x == "" else str(int(x)) + "%")

# %% [markdown]
# # Write All Clusters

# %%
col_fff = "out_file"
fff = np.array(cr.pp.construct_file(directory=direc, panel_id=panel))
bff = np.array([os.path.basename(i) for i in fff])  # base path names
samps = np.array([i.split("__")[2].split("-")[0] for i in fff])
for x in metadata[cso]:
    m_f = metadata[metadata[cso] == x][
        "out_file"].iloc[0]  # ...use to find unconventionally-named files
    locx = np.where(samps == x)[0] if pd.isnull(
        m_f) else np.where(bff == m_f)[0]
    metadata.loc[metadata[cso] == x, col_fff] = fff[locx[0]] if (
        len(locx) > 0) else np.nan  # assign output file to metadata row
metadata = metadata.dropna(subset=[col_fff]).drop_duplicates().set_index(cso)

# %%
# Load Spatial Data
for libid in samp_ids:
    if not os.path.exists(os.path.join(out_dir, samp_ids[libid] + ".h5ad")):
        print(f"\n\nWarning: Critical file(s) for {libid} not found.\n\n")
        continue
    self = cr.Spatial(metadata.loc[libid]["out_file"],
                      library_id=samp_ids[libid])
    self.update_from_h5ad(os.path.join(out_dir, samp_ids[libid] + ".h5ad"))
    if c_t not in self.rna.obs.columns:
        print(f"\n\nWarning: {c_t} column for {libid} not found.\n\n")
        continue
    self.write_clusters(out_dir, col_cell_type=c_t, overwrite=True,
                        file_prefix=f"{self._library_id}__",
                        n_top="find_markers")

# %%
c_t = "leiden_res1pt5_dist0_npc30"
# Faster way for spatial data

# import scanpy as sc

# c_t = "leiden_res1pt5_dist0_npc30"
clusterings = ["res1pt5_dist0_npc30"]

for libid in samp_ids:
    if not os.path.exists(os.path.join(out_dir, samp_ids[libid] + ".h5ad")):
        print(f"\n\nWarning: Critical file(s) for {libid} not found.\n\n")
        continue
    adata = sc.read(os.path.join(out_dir, samp_ids[libid] + ".h5ad"))
    for r in clusterings:
        c_t = f"leiden_{r}"
        if c_t not in adata.obs.columns:
            print(f"\n\nWarning: {c_t} column for {libid} not found.\n\n")
            continue
        fff = os.path.join(out_dir, f"{samp_ids[libid]}__{c_t}.csv")
        adata.obs.set_index("cell_id")[c_t].to_frame("group").to_csv(fff)
        fmr = pd.read_excel(os.path.join(
            out_dir, "annotation_dictionaries/annotations_all.xlsx"),
                            index_col=[0, 1]).iloc[:, :3].astype(str).dropna()
        if f"{samp_ids[libid]}___leiden_{r}_dictionary.xlsx" not in [
                v[0] for v in fmr.index]:
            print(f"{libid} not in annotation dictionary.")
            continue
        else:
            print(f"{libid} annotated.")
        fmr = fmr.loc[f"{samp_ids[libid]}___leiden_{r}_dictionary.xlsx"]
        mans = dict(fmr["annotation"])
        adata.obs.loc[:, f"manual_{r}"] = adata.obs[f"leiden_{r}"].astype(
            int).astype(str).replace(mans)  # Leiden -> manual annotation
        adata.obs.loc[adata.obs[f"manual_{r}"].isnull(
            ), f"manual_{r}"] = adata.obs.loc[adata.obs[
                f"manual_{r}"].isnull(), f"leiden_{r}"].astype(str)
        adata.obs.loc[:, f"manual_{r}"] = adata.obs[
            f"manual_{r}"].astype("category")  # as categorical
        fff = os.path.join(out_dir, f"{samp_ids[libid]}__manual_{r}.csv")
        adata.obs.set_index("cell_id")[f"manual_{r}"].to_frame(
            "group").to_csv(fff)
